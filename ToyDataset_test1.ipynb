# %%
"""
    Author: Moustafa Alzantot (malzantot@ucla.edu)
    All rights reserved.
"""
import torch
import collections
import os
import soundfile as sf
from torch.utils.data import DataLoader, Dataset
import numpy as np
from joblib import Parallel, delayed
import h5py

LOGICAL_DATA_ROOT = 'LA'
PHISYCAL_DATA_ROOT = 'data_physical'

ASVFile = collections.namedtuple('ASVFile',
    ['speaker_id', 'file_name', 'path', 'sys_id', 'key'])

class ASVDataset(Dataset):
    """ Utility class to load  train/dev datatsets """
    def __init__(self,
        LOGICAL_DATA_ROOT='LA',
        LOGICAL_PROTOCOL_DIR='LA',
        transform=None, 
        is_train=True,
        is_eval=False,
        sample_size=None,
        feature_name=None,
        eval_part=0):
        data_root = LOGICAL_DATA_ROOT
        track = 'LA'

        assert feature_name is not None, 'must provide feature name'
        self.track = track
        self.prefix = 'ASVspoof2019_{}'.format(track)
        v1_suffix = ''

        self.sysid_dict = {
            'human': 0,  # bonafide speech
            'spoof': 1, # Spoofed signal
        }
        
        self.is_eval = is_eval
        self.sysid_dict_inv = {v:k for k,v in self.sysid_dict.items()}
        self.data_root = data_root
        self.dset_name = 'eval' if is_eval else 'train' if is_train else 'dev'
        self.protocols_fname = 'eval_short.trn' if is_eval else 'train_short.trn' if is_train else 'dev_short.trn'
        self.protocols_dir = os.path.join(self.data_root,
            '{}_protocols/'.format(self.prefix))
        
        self.protocols_dir = LOGICAL_PROTOCOL_DIR
        
        self.files_dir = os.path.join(self.data_root, '{}_{}'.format(
            self.prefix, 'train')+v1_suffix, 'flac') # we just take from the train folder, sorry
        self.protocols_fname = os.path.join(self.protocols_dir,
            'ASVspoof2019.{}.cm.{}.txt'.format(track, self.protocols_fname))
        self.cache_fname = 'cache_{}_{}_{}.npy'.format(self.dset_name, track, feature_name)
        
        self.transform = transform
        if os.path.exists(self.cache_fname):
            self.data_x, self.data_y, self.data_sysid, self.files_meta = torch.load(self.cache_fname)
            print('Dataset loaded from cache ', self.cache_fname)
        else:
            self.files_meta = self.parse_protocols_file(self.protocols_fname)
            data = list(map(self.read_file, self.files_meta))
            self.data_x, self.data_y, self.data_sysid = map(list, zip(*data))
            if self.transform:
                # self.data_x = list(map(self.transform, self.data_x)) 
                self.data_x = Parallel(n_jobs=4, prefer='threads')(delayed(self.transform)(x) for x in self.data_x)
            torch.save((self.data_x, self.data_y, self.data_sysid, self.files_meta), self.cache_fname)
            print('Dataset saved to cache ', self.cache_fname)
        if sample_size:
            select_idx = np.random.choice(len(self.files_meta), size=(sample_size,), replace=True).astype(np.int32)
            self.files_meta= [self.files_meta[x] for x in select_idx]
            self.data_x = [self.data_x[x] for x in select_idx]
            self.data_y = [self.data_y[x] for x in select_idx]
            self.data_sysid = [self.data_sysid[x] for x in select_idx]
        self.length = len(self.data_x)

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        x = self.data_x[idx]
        y = self.data_y[idx]
        return x, y, self.files_meta[idx]

    def read_file(self, meta):
        #data_x, sample_rate = sf.read(meta.path)
        data_x = read_and_preprocess_file(meta.path)
        data_y = meta.key
        # MODIFYING THIS TO INT 
        return data_x, int(data_y), meta.sys_id

    def _parse_line(self, line):
        tokens = line.strip().split(' ')
        print("In parse")
        print(line)
        return ASVFile(speaker_id=tokens[0],
            file_name=tokens[1],
            path=os.path.join(self.files_dir, tokens[1] + '.flac'),
            sys_id=self.sysid_dict[tokens[3]],
            key=int(tokens[3] == 'human'))

    def parse_protocols_file(self, protocols_fname):
        lines = open(protocols_fname).readlines()
        files_meta = map(self._parse_line, lines)
        return list(files_meta)


# if __name__ == '__main__':
#    train_loader = ASVDataset(LOGICAL_DATA_ROOT, is_train=True)
#    assert len(train_loader) == 25380, 'Incorrect size of training set.'
#    dev_loader = ASVDataset(LOGICAL_DATA_ROOT, is_train=False)
#    assert len(dev_loader) == 24844, 'Incorrect size of dev set.'

# %%
import librosa

int16_max = (2 ** 15) - 1

def read_and_preprocess_file(path: str, sampling_rate=16000) -> np.array:
    """
    Read audio file to spectrogram.
    By reading it to some other intermediate form first.
    ...I don't know, i just hope this works, i basically have no idea what i'm doing. :D
    By default, uses the same sampling rate that was used in AutoSpeech.
    
    Params:
        path: file location
        sampling_rate: desired sampling rate (will resample the supplied wav if needed)
        
    Retruns:
        spectrogram of supplied file
    """
    wav, sr = librosa.load(path, sr=sampling_rate)
    wav = normalize_volume(wav, increase_only=True)
    spectrogram = wav_to_spectrogram(wav) # obtain (freq, time) spectrogram
    # Resample the spectrogram to bound its duration.
    # It must be transposed to (time, freq) first
    spectrogram = adjust_duration(spectrogram.T, partial_n_frames=300)
    # Re-transpose to get it back to (freq, time) shape
    return spectrogram.T 
    
    

def normalize_volume(wav, target_dBFS=-30, increase_only=False, decrease_only=False):
    """
    Normalizes volume of supplied wav.
    I literally copied this from autospeech and changed target_dBFS to their default value.
    """
    if increase_only and decrease_only:
        raise ValueError("Both increase only and decrease only are set")
    rms = np.sqrt(np.mean((wav * int16_max) ** 2))
    wave_dBFS = 20 * np.log10(rms / int16_max)
    dBFS_change = target_dBFS - wave_dBFS
    if dBFS_change < 0 and increase_only or dBFS_change > 0 and decrease_only:
        return wav
    return wav * (10 ** (dBFS_change / 20))


def wav_to_spectrogram(wav, sampling_rate=16000, window_step=10, window_length=25, n_fft=512):
    """
    Returns: (freq, time)
    """
    frames = np.abs(librosa.core.stft(
        wav,
        n_fft=n_fft,
        hop_length=int(sampling_rate * window_step / 1000),
        win_length=int(sampling_rate * window_length / 1000),
    ))
    
    return frames.astype(np.float32)

def adjust_duration(feature, partial_n_frames=10000):
    """
    Re-adapted from AutoSpeech again...
    """
    if feature.shape[0] <= partial_n_frames:
        start = 0
        while feature.shape[0] < partial_n_frames:
            feature = np.repeat(feature, 2, axis=0)
    else:
        start = np.random.randint(0, feature.shape[0] - partial_n_frames)
    end = start + partial_n_frames
    return feature[start:end]

# %%
ds_train = ASVDataset(feature_name='questo_train', is_train=True)
# Out:
# Dataset loaded from cache  cache_train_LA_questo_train.npy

# %%
ds_dev = ASVDataset(feature_name='questo_devvv', is_train=False)
# Out:
# In parse
# flac LA_T_5163922 A03 spoof
#
# ['flac', 'LA_T_5163922', 'A03', 'spoof']
# In parse
# flac LA_T_4269497 A02 spoof
#
# ['flac', 'LA_T_4269497', 'A02', 'spoof']
# In parse
# flac LA_T_1036998 A02 spoof
#
# ['flac', 'LA_T_1036998', 'A02', 'spoof']
# In parse
# flac LA_T_3781714 A01 spoof
#
# ['flac', 'LA_T_3781714', 'A01', 'spoof']
# In parse
# flac LA_T_3051735 A06 spoof
#
# ['flac', 'LA_T_3051735', 'A06', 'spoof']
# In parse
# flac LA_T_5148309 A01 spoof
#
# ['flac', 'LA_T_5148309', 'A01', 'spoof']
# In parse
# flac LA_T_6143831 A01 spoof
#
# ['flac', 'LA_T_6143831', 'A01', 'spoof']
# In parse
# flac LA_T_8570091 A05 spoof
#
# ['flac', 'LA_T_8570091', 'A05', 'spoof']
# In parse
# flac LA_T_5261598 A05 spoof
#
# ['flac', 'LA_T_5261598', 'A05', 'spoof']
# In parse
# flac LA_T_8555100 A01 spoof
#
# ['flac', 'LA_T_8555100', 'A01', 'spoof']
# In parse
# flac LA_T_3141223 human human
#
# ['flac', 'LA_T_3141223', 'human', 'human']
# In parse
# flac LA_T_9039580 A02 spoof
#
# ['flac', 'LA_T_9039580', 'A02', 'spoof']
# In parse
# flac LA_T_1724630 A01 spoof
#
# ['flac', 'LA_T_1724630', 'A01', 'spoof']
# In parse
# flac LA_T_9234368 A04 spoof
#
# ['flac', 'LA_T_9234368', 'A04', 'spoof']
# In parse
# flac LA_T_8258579 A01 spoof
#
# ['flac', 'LA_T_8258579', 'A01', 'spoof']
# In parse
# flac LA_T_2413287 A05 spoof
#
# ['flac', 'LA_T_2413287', 'A05', 'spoof']
# In parse
# flac LA_T_6284251 A04 spoof
#
# ['flac', 'LA_T_6284251', 'A04', 'spoof']
# In parse
# flac LA_T_8484126 A06 spoof
#
# ['flac', 'LA_T_8484126', 'A06', 'spoof']
# In parse
# flac LA_T_5546324 A05 spoof
#
# ['flac', 'LA_T_5546324', 'A05', 'spoof']
# In parse
# flac LA_T_1202428 A06 spoof
#
# ['flac', 'LA_T_1202428', 'A06', 'spoof']
# In parse
# flac LA_T_7506040 A03 spoof
#
# ['flac', 'LA_T_7506040', 'A03', 'spoof']
# In parse
# flac LA_T_8197665 A03 spoof
#
# ['flac', 'LA_T_8197665', 'A03', 'spoof']
# In parse
# flac LA_T_3864921 A05 spoof
#
# ['flac', 'LA_T_3864921', 'A05', 'spoof']
# In parse
# flac LA_T_4519471 A06 spoof
#
# ['flac', 'LA_T_4519471', 'A06', 'spoof']
# In parse
# flac LA_T_4802892 A05 spoof
#
# ['flac', 'LA_T_4802892', 'A05', 'spoof']
# In parse
# flac LA_T_5628240 A03 spoof
#
# ['flac', 'LA_T_5628240', 'A03', 'spoof']
# In parse
# flac LA_T_2021625 A05 spoof
#
# ['flac', 'LA_T_2021625', 'A05', 'spoof']
# In parse
# flac LA_T_6236387 A04 spoof
#
# ['flac', 'LA_T_6236387', 'A04', 'spoof']
# In parse
# flac LA_T_9417097 A05 spoof
#
# ['flac', 'LA_T_9417097', 'A05', 'spoof']
# In parse
# flac LA_T_9990195 A03 spoof
#
# ['flac', 'LA_T_9990195', 'A03', 'spoof']
# In parse
# flac LA_T_2936703 human human
#
# ['flac', 'LA_T_2936703', 'human', 'human']
# In parse
# flac LA_T_4621109 A03 spoof
#
# ['flac', 'LA_T_4621109', 'A03', 'spoof']
# In parse
# flac LA_T_5240719 A01 spoof
#
# ['flac', 'LA_T_5240719', 'A01', 'spoof']
# In parse
# flac LA_T_9087756 A06 spoof
#
# ['flac', 'LA_T_9087756', 'A06', 'spoof']
# In parse
# flac LA_T_7226201 A02 spoof
#
# ['flac', 'LA_T_7226201', 'A02', 'spoof']
# In parse
# flac LA_T_2260085 A01 spoof
#
# ['flac', 'LA_T_2260085', 'A01', 'spoof']
# In parse
# flac LA_T_1160239 A03 spoof
#
# ['flac', 'LA_T_1160239', 'A03', 'spoof']
# In parse
# flac LA_T_8461914 A04 spoof
#
# ['flac', 'LA_T_8461914', 'A04', 'spoof']
# In parse
# flac LA_T_3551279 A04 spoof
#
# ['flac', 'LA_T_3551279', 'A04', 'spoof']
# In parse
# flac LA_T_8311830 A05 spoof
#
# ['flac', 'LA_T_8311830', 'A05', 'spoof']
# In parse
# flac LA_T_7744399 A03 spoof
#
# ['flac', 'LA_T_7744399', 'A03', 'spoof']
# In parse
# flac LA_T_1486451 human human
#
# ['flac', 'LA_T_1486451', 'human', 'human']
# In parse
# flac LA_T_4250576 A03 spoof
#
# ['flac', 'LA_T_4250576', 'A03', 'spoof']
# In parse
# flac LA_T_3692595 human human
#
# ['flac', 'LA_T_3692595', 'human', 'human']
# In parse
# flac LA_T_6626053 A03 spoof
#
# ['flac', 'LA_T_6626053', 'A03', 'spoof']
# In parse
# flac LA_T_3958984 A06 spoof
#
# ['flac', 'LA_T_3958984', 'A06', 'spoof']
# In parse
# flac LA_T_6494050 A02 spoof
#
# ['flac', 'LA_T_6494050', 'A02', 'spoof']
# In parse
# flac LA_T_5861037 A01 spoof
#
# ['flac', 'LA_T_5861037', 'A01', 'spoof']
# In parse
# flac LA_T_3732826 A06 spoof
#
# ['flac', 'LA_T_3732826', 'A06', 'spoof']
# In parse
# flac LA_T_5621579 A05 spoof
#
# ['flac', 'LA_T_5621579', 'A05', 'spoof']
# In parse
# flac LA_T_2032733 human human
#
# ['flac', 'LA_T_2032733', 'human', 'human']
# In parse
# flac LA_T_5920672 A04 spoof
#
# ['flac', 'LA_T_5920672', 'A04', 'spoof']
# In parse
# flac LA_T_1958041 A01 spoof
#
# ['flac', 'LA_T_1958041', 'A01', 'spoof']
# In parse
# flac LA_T_6558068 A01 spoof
#
# ['flac', 'LA_T_6558068', 'A01', 'spoof']
# In parse
# flac LA_T_6886887 A04 spoof
#
# ['flac', 'LA_T_6886887', 'A04', 'spoof']
# In parse
# flac LA_T_8367167 A06 spoof
#
# ['flac', 'LA_T_8367167', 'A06', 'spoof']
# In parse
# flac LA_T_6871193 A02 spoof
#
# ['flac', 'LA_T_6871193', 'A02', 'spoof']
# In parse
# flac LA_T_8919148 A01 spoof
#
# ['flac', 'LA_T_8919148', 'A01', 'spoof']
# In parse
# flac LA_T_6085526 A04 spoof
#
# ['flac', 'LA_T_6085526', 'A04', 'spoof']
# In parse
# flac LA_T_2198931 A06 spoof
#
# ['flac', 'LA_T_2198931', 'A06', 'spoof']
# In parse
# flac LA_T_9725571 A04 spoof
#
# ['flac', 'LA_T_9725571', 'A04', 'spoof']
# In parse
# flac LA_T_2248930 A05 spoof
#
# ['flac', 'LA_T_2248930', 'A05', 'spoof']
# In parse
# flac LA_T_2310598 A04 spoof
#
# ['flac', 'LA_T_2310598', 'A04', 'spoof']
# In parse
# flac LA_T_7341994 A05 spoof
#
# ['flac', 'LA_T_7341994', 'A05', 'spoof']
# In parse
# flac LA_T_4723466 A04 spoof
#
# ['flac', 'LA_T_4723466', 'A04', 'spoof']
# In parse
# flac LA_T_6002614 A06 spoof
#
# ['flac', 'LA_T_6002614', 'A06', 'spoof']
# In parse
# flac LA_T_4859127 A01 spoof
#
# ['flac', 'LA_T_4859127', 'A01', 'spoof']
# In parse
# flac LA_T_7394905 A01 spoof
#
# ['flac', 'LA_T_7394905', 'A01', 'spoof']
# In parse
# flac LA_T_1362808 A05 spoof
#
# ['flac', 'LA_T_1362808', 'A05', 'spoof']
# In parse
# flac LA_T_7084634 human human
#
# ['flac', 'LA_T_7084634', 'human', 'human']
# In parse
# flac LA_T_8332714 A05 spoof
#
# ['flac', 'LA_T_8332714', 'A05', 'spoof']
# In parse
# flac LA_T_6328038 A03 spoof
#
# ['flac', 'LA_T_6328038', 'A03', 'spoof']
# In parse
# flac LA_T_9331964 A06 spoof
#
# ['flac', 'LA_T_9331964', 'A06', 'spoof']
# In parse
# flac LA_T_3566209 A01 spoof
#
# ['flac', 'LA_T_3566209', 'A01', 'spoof']
# In parse
# flac LA_T_9491057 A06 spoof
#
# ['flac', 'LA_T_9491057', 'A06', 'spoof']
# In parse
# flac LA_T_2130469 A01 spoof
#
# ['flac', 'LA_T_2130469', 'A01', 'spoof']
# In parse
# flac LA_T_1647761 A06 spoof
#
# ['flac', 'LA_T_1647761', 'A06', 'spoof']
# In parse
# flac LA_T_6468314 A06 spoof
#
# ['flac', 'LA_T_6468314', 'A06', 'spoof']
# In parse
# flac LA_T_6185775 A04 spoof
#
# ['flac', 'LA_T_6185775', 'A04', 'spoof']
# In parse
# flac LA_T_3204505 A05 spoof
#
# ['flac', 'LA_T_3204505', 'A05', 'spoof']
# In parse
# flac LA_T_6239874 human human
#
# ['flac', 'LA_T_6239874', 'human', 'human']
# In parse
# flac LA_T_5607947 A04 spoof
#
# ['flac', 'LA_T_5607947', 'A04', 'spoof']
# In parse
# flac LA_T_3293764 A04 spoof
#
# ['flac', 'LA_T_3293764', 'A04', 'spoof']
# In parse
# flac LA_T_3414698 A01 spoof
#
# ['flac', 'LA_T_3414698', 'A01', 'spoof']
# In parse
# flac LA_T_4356385 A05 spoof
#
# ['flac', 'LA_T_4356385', 'A05', 'spoof']
# In parse
# flac LA_T_3639692 A06 spoof
#
# ['flac', 'LA_T_3639692', 'A06', 'spoof']
# In parse
# flac LA_T_8758621 A02 spoof
#
# ['flac', 'LA_T_8758621', 'A02', 'spoof']
# In parse
# flac LA_T_7384221 A01 spoof
#
# ['flac', 'LA_T_7384221', 'A01', 'spoof']
# In parse
# flac LA_T_6559140 A06 spoof
#
# ['flac', 'LA_T_6559140', 'A06', 'spoof']
# In parse
# flac LA_T_6093991 human human
#
# ['flac', 'LA_T_6093991', 'human', 'human']
# In parse
# flac LA_T_5629248 A02 spoof
#
# ['flac', 'LA_T_5629248', 'A02', 'spoof']
# In parse
# flac LA_T_3263570 A03 spoof
#
# ['flac', 'LA_T_3263570', 'A03', 'spoof']
# In parse
# flac LA_T_2329123 A04 spoof
#
# ['flac', 'LA_T_2329123', 'A04', 'spoof']
# In parse
# flac LA_T_3689339 A03 spoof
#
# ['flac', 'LA_T_3689339', 'A03', 'spoof']
# In parse
# flac LA_T_9017148 A04 spoof
#
# ['flac', 'LA_T_9017148', 'A04', 'spoof']
# In parse
# flac LA_T_3457892 A06 spoof
#
# ['flac', 'LA_T_3457892', 'A06', 'spoof']
# In parse
# flac LA_T_5951648 A06 spoof
#
# ['flac', 'LA_T_5951648', 'A06', 'spoof']
# In parse
# flac LA_T_2202113 A05 spoof
#
# ['flac', 'LA_T_2202113', 'A05', 'spoof']
# In parse
# flac LA_T_4512109 A01 spoof
#
# ['flac', 'LA_T_4512109', 'A01', 'spoof']
# In parse
# flac LA_T_5178051 A04 spoof
#
# ['flac', 'LA_T_5178051', 'A04', 'spoof']
# In parse
# flac LA_T_7702298 A06 spoof
#
# ['flac', 'LA_T_7702298', 'A06', 'spoof']
# In parse
# flac LA_T_5570596 A02 spoof
#
# ['flac', 'LA_T_5570596', 'A02', 'spoof']
# In parse
# flac LA_T_4207973 A03 spoof
#
# ['flac', 'LA_T_4207973', 'A03', 'spoof']
# In parse
# flac LA_T_1542243 A04 spoof
#
# ['flac', 'LA_T_1542243', 'A04', 'spoof']
# In parse
# flac LA_T_1792767 human human
#
# ['flac', 'LA_T_1792767', 'human', 'human']
# In parse
# flac LA_T_6281759 A04 spoof
#
# ['flac', 'LA_T_6281759', 'A04', 'spoof']
# In parse
# flac LA_T_5836873 A04 spoof
#
# ['flac', 'LA_T_5836873', 'A04', 'spoof']
# In parse
# flac LA_T_2062843 A04 spoof
#
# ['flac', 'LA_T_2062843', 'A04', 'spoof']
# In parse
# flac LA_T_3772667 human human
#
# ['flac', 'LA_T_3772667', 'human', 'human']
# In parse
# flac LA_T_9602636 A03 spoof
#
# ['flac', 'LA_T_9602636', 'A03', 'spoof']
# In parse
# flac LA_T_3922717 A02 spoof
#
# ['flac', 'LA_T_3922717', 'A02', 'spoof']
# In parse
# flac LA_T_7856276 A06 spoof
#
# ['flac', 'LA_T_7856276', 'A06', 'spoof']
# In parse
# flac LA_T_1836557 human human
#
# ['flac', 'LA_T_1836557', 'human', 'human']
# In parse
# flac LA_T_5964458 A01 spoof
#
# ['flac', 'LA_T_5964458', 'A01', 'spoof']
# In parse
# flac LA_T_6763144 A03 spoof
#
# ['flac', 'LA_T_6763144', 'A03', 'spoof']
# In parse
# flac LA_T_5041180 A05 spoof
#
# ['flac', 'LA_T_5041180', 'A05', 'spoof']
# In parse
# flac LA_T_1728069 A06 spoof
#
# ['flac', 'LA_T_1728069', 'A06', 'spoof']
# In parse
# flac LA_T_1562164 human human
#
# ['flac', 'LA_T_1562164', 'human', 'human']
# In parse
# flac LA_T_6320696 A03 spoof
#
# ['flac', 'LA_T_6320696', 'A03', 'spoof']
# In parse
# flac LA_T_8398921 A04 spoof
#
# ['flac', 'LA_T_8398921', 'A04', 'spoof']
# In parse
# flac LA_T_6997003 A05 spoof
#
# ['flac', 'LA_T_6997003', 'A05', 'spoof']
# In parse
# flac LA_T_6518010 A01 spoof
#
# ['flac', 'LA_T_6518010', 'A01', 'spoof']
# In parse
# flac LA_T_3268169 human human
#
# ['flac', 'LA_T_3268169', 'human', 'human']
# In parse
# flac LA_T_7853928 A02 spoof
#
# ['flac', 'LA_T_7853928', 'A02', 'spoof']
# In parse
# flac LA_T_8057574 A06 spoof
#
# ['flac', 'LA_T_8057574', 'A06', 'spoof']
# In parse
# flac LA_T_7929015 A06 spoof
#
# ['flac', 'LA_T_7929015', 'A06', 'spoof']
# In parse
# flac LA_T_4732682 A01 spoof
#
# ['flac', 'LA_T_4732682', 'A01', 'spoof']
# In parse
# flac LA_T_9376880 A03 spoof
#
# ['flac', 'LA_T_9376880', 'A03', 'spoof']
# In parse
# flac LA_T_6735273 A04 spoof
#
# ['flac', 'LA_T_6735273', 'A04', 'spoof']
# In parse
# flac LA_T_5634266 A05 spoof
#
# ['flac', 'LA_T_5634266', 'A05', 'spoof']
# In parse
# flac LA_T_6434702 human human
#
# ['flac', 'LA_T_6434702', 'human', 'human']
# In parse
# flac LA_T_8710866 human human
#
# ['flac', 'LA_T_8710866', 'human', 'human']
# In parse
# flac LA_T_7222202 A04 spoof
#
# ['flac', 'LA_T_7222202', 'A04', 'spoof']
# In parse
# flac LA_T_5763454 A06 spoof
#
# ['flac', 'LA_T_5763454', 'A06', 'spoof']
# In parse
# flac LA_T_9864611 A01 spoof
#
# ['flac', 'LA_T_9864611', 'A01', 'spoof']
# In parse
# flac LA_T_9556989 A03 spoof
#
# ['flac', 'LA_T_9556989', 'A03', 'spoof']
# In parse
# flac LA_T_6439800 A01 spoof
#
# ['flac', 'LA_T_6439800', 'A01', 'spoof']
# In parse
# flac LA_T_7263802 A03 spoof
#
# ['flac', 'LA_T_7263802', 'A03', 'spoof']
# In parse
# flac LA_T_3939359 A06 spoof
#
# ['flac', 'LA_T_3939359', 'A06', 'spoof']
# In parse
# flac LA_T_4528605 A04 spoof
#
# ['flac', 'LA_T_4528605', 'A04', 'spoof']
# In parse
# flac LA_T_3219112 A05 spoof
#
# ['flac', 'LA_T_3219112', 'A05', 'spoof']
# In parse
# flac LA_T_6690126 A06 spoof
#
# ['flac', 'LA_T_6690126', 'A06', 'spoof']
# In parse
# flac LA_T_3916603 A03 spoof
#
# ['flac', 'LA_T_3916603', 'A03', 'spoof']
# In parse
# flac LA_T_4123026 A04 spoof
#
# ['flac', 'LA_T_4123026', 'A04', 'spoof']
# In parse
# flac LA_T_1708175 A02 spoof
#
# ['flac', 'LA_T_1708175', 'A02', 'spoof']
# In parse
# flac LA_T_4261149 A04 spoof
#
# ['flac', 'LA_T_4261149', 'A04', 'spoof']
# In parse
# flac LA_T_6248805 A01 spoof
#
# ['flac', 'LA_T_6248805', 'A01', 'spoof']
# In parse
# flac LA_T_9058481 A06 spoof
#
# ['flac', 'LA_T_9058481', 'A06', 'spoof']
# In parse
# flac LA_T_2383876 A02 spoof
#
# ['flac', 'LA_T_2383876', 'A02', 'spoof']
# In parse
# flac LA_T_7201904 A02 spoof
#
# ['flac', 'LA_T_7201904', 'A02', 'spoof']
# In parse
# flac LA_T_2127859 A05 spoof
#
# ['flac', 'LA_T_2127859', 'A05', 'spoof']
# In parse
# flac LA_T_9350824 A02 spoof
#
# ['flac', 'LA_T_9350824', 'A02', 'spoof']
# In parse
# flac LA_T_4571454 A04 spoof
#
# ['flac', 'LA_T_4571454', 'A04', 'spoof']
# In parse
# flac LA_T_9206685 A03 spoof
#
# ['flac', 'LA_T_9206685', 'A03', 'spoof']
# In parse
# flac LA_T_4894239 A04 spoof
#
# ['flac', 'LA_T_4894239', 'A04', 'spoof']
# In parse
# flac LA_T_6530543 A06 spoof
#
# ['flac', 'LA_T_6530543', 'A06', 'spoof']
# In parse
# flac LA_T_1077649 A05 spoof
#
# ['flac', 'LA_T_1077649', 'A05', 'spoof']
# In parse
# flac LA_T_7683871 A04 spoof
#
# ['flac', 'LA_T_7683871', 'A04', 'spoof']
# In parse
# flac LA_T_3580518 A06 spoof
#
# ['flac', 'LA_T_3580518', 'A06', 'spoof']
# In parse
# flac LA_T_4401196 A05 spoof
#
# ['flac', 'LA_T_4401196', 'A05', 'spoof']
# In parse
# flac LA_T_8035781 human human
#
# ['flac', 'LA_T_8035781', 'human', 'human']
# In parse
# flac LA_T_8356686 A05 spoof
#
# ['flac', 'LA_T_8356686', 'A05', 'spoof']
# In parse
# flac LA_T_8765986 A01 spoof
#
# ['flac', 'LA_T_8765986', 'A01', 'spoof']
# In parse
# flac LA_T_1262924 A03 spoof
#
# ['flac', 'LA_T_1262924', 'A03', 'spoof']
# In parse
# flac LA_T_1446479 A05 spoof
#
# ['flac', 'LA_T_1446479', 'A05', 'spoof']
# In parse
# flac LA_T_9378157 human human
#
# ['flac', 'LA_T_9378157', 'human', 'human']
# In parse
# flac LA_T_3196822 A05 spoof
#
# ['flac', 'LA_T_3196822', 'A05', 'spoof']
# In parse
# flac LA_T_5497967 A01 spoof
#
# ['flac', 'LA_T_5497967', 'A01', 'spoof']
# In parse
# flac LA_T_2369067 A03 spoof
#
# ['flac', 'LA_T_2369067', 'A03', 'spoof']
# In parse
# flac LA_T_1252325 A02 spoof
#
# ['flac', 'LA_T_1252325', 'A02', 'spoof']
# In parse
# flac LA_T_8705756 A02 spoof
#
# ['flac', 'LA_T_8705756', 'A02', 'spoof']
# In parse
# flac LA_T_4104320 A03 spoof
#
# ['flac', 'LA_T_4104320', 'A03', 'spoof']
# In parse
# flac LA_T_4007174 A06 spoof
#
# ['flac', 'LA_T_4007174', 'A06', 'spoof']
# In parse
# flac LA_T_5513029 A03 spoof
#
# ['flac', 'LA_T_5513029', 'A03', 'spoof']
# In parse
# flac LA_T_1940419 human human
#
# ['flac', 'LA_T_1940419', 'human', 'human']
# In parse
# flac LA_T_2523333 A03 spoof
#
# ['flac', 'LA_T_2523333', 'A03', 'spoof']
# In parse
# flac LA_T_9424477 A04 spoof
#
# ['flac', 'LA_T_9424477', 'A04', 'spoof']
# In parse
# flac LA_T_6072163 A01 spoof
#
# ['flac', 'LA_T_6072163', 'A01', 'spoof']
# In parse
# flac LA_T_4165709 A01 spoof
#
# ['flac', 'LA_T_4165709', 'A01', 'spoof']
# In parse
# flac LA_T_4654238 A04 spoof
#
# ['flac', 'LA_T_4654238', 'A04', 'spoof']
# In parse
# flac LA_T_6878999 A04 spoof
#
# ['flac', 'LA_T_6878999', 'A04', 'spoof']
# In parse
# flac LA_T_1163771 A02 spoof
#
# ['flac', 'LA_T_1163771', 'A02', 'spoof']
# In parse
# flac LA_T_6518809 human human
#
# ['flac', 'LA_T_6518809', 'human', 'human']
# In parse
# flac LA_T_3740126 A01 spoof
#
# ['flac', 'LA_T_3740126', 'A01', 'spoof']
# In parse
# flac LA_T_7468821 A04 spoof
#
# ['flac', 'LA_T_7468821', 'A04', 'spoof']
# In parse
# flac LA_T_8105569 A02 spoof
#
# ['flac', 'LA_T_8105569', 'A02', 'spoof']
# In parse
# flac LA_T_8968944 A03 spoof
#
# ['flac', 'LA_T_8968944', 'A03', 'spoof']
# In parse
# flac LA_T_5866008 A06 spoof
#
# ['flac', 'LA_T_5866008', 'A06', 'spoof']
# In parse
# flac LA_T_6034181 A01 spoof
#
# ['flac', 'LA_T_6034181', 'A01', 'spoof']
# In parse
# flac LA_T_1854925 A04 spoof
#
# ['flac', 'LA_T_1854925', 'A04', 'spoof']
# In parse
# flac LA_T_1781151 A01 spoof
#
# ['flac', 'LA_T_1781151', 'A01', 'spoof']
# In parse
# flac LA_T_8380191 A05 spoof
#
# ['flac', 'LA_T_8380191', 'A05', 'spoof']
# In parse
# flac LA_T_1584006 A04 spoof
#
# ['flac', 'LA_T_1584006', 'A04', 'spoof']
# In parse
# flac LA_T_8721428 human human
#
# ['flac', 'LA_T_8721428', 'human', 'human']
# In parse
# flac LA_T_3357680 A06 spoof
#
# ['flac', 'LA_T_3357680', 'A06', 'spoof']
# In parse
# flac LA_T_7597419 A01 spoof
#
# ['flac', 'LA_T_7597419', 'A01', 'spoof']
# In parse
# flac LA_T_5791737 human human
#
# ['flac', 'LA_T_5791737', 'human', 'human']
# In parse
# flac LA_T_6441166 human human
#
# ['flac', 'LA_T_6441166', 'human', 'human']
# In parse
# flac LA_T_1433631 human human
#
# ['flac', 'LA_T_1433631', 'human', 'human']
# In parse
# flac LA_T_6761178 A02 spoof
#
# ['flac', 'LA_T_6761178', 'A02', 'spoof']
# In parse
# flac LA_T_9699345 A06 spoof
#
# ['flac', 'LA_T_9699345', 'A06', 'spoof']
# In parse
# flac LA_T_6624843 A06 spoof
#
# ['flac', 'LA_T_6624843', 'A06', 'spoof']
# In parse
# flac LA_T_6481379 A03 spoof
#
# ['flac', 'LA_T_6481379', 'A03', 'spoof']
# In parse
# flac LA_T_1065455 A03 spoof
#
# ['flac', 'LA_T_1065455', 'A03', 'spoof']
# In parse
# flac LA_T_2881097 A06 spoof
#
# ['flac', 'LA_T_2881097', 'A06', 'spoof']
# In parse
# flac LA_T_1370922 A03 spoof
#
# ['flac', 'LA_T_1370922', 'A03', 'spoof']
# In parse
# flac LA_T_8492730 A06 spoof
#
# ['flac', 'LA_T_8492730', 'A06', 'spoof']
# In parse
# flac LA_T_4466421 A06 spoof
#
# ['flac', 'LA_T_4466421', 'A06', 'spoof']
# In parse
# flac LA_T_6369971 A02 spoof
#
# ['flac', 'LA_T_6369971', 'A02', 'spoof']
# In parse
# flac LA_T_8154726 A01 spoof
#
# ['flac', 'LA_T_8154726', 'A01', 'spoof']
# In parse
# flac LA_T_1256941 A05 spoof
#
# ['flac', 'LA_T_1256941', 'A05', 'spoof']
# In parse
# flac LA_T_6253905 A05 spoof
#
# ['flac', 'LA_T_6253905', 'A05', 'spoof']
# In parse
# flac LA_T_5293684 A01 spoof
#
# ['flac', 'LA_T_5293684', 'A01', 'spoof']
# In parse
# flac LA_T_3472831 A05 spoof
#
# ['flac', 'LA_T_3472831', 'A05', 'spoof']
# In parse
# flac LA_T_1886277 A02 spoof
#
# ['flac', 'LA_T_1886277', 'A02', 'spoof']
# In parse
# flac LA_T_2342853 A06 spoof
#
# ['flac', 'LA_T_2342853', 'A06', 'spoof']
# In parse
# flac LA_T_1029621 A05 spoof
#
# ['flac', 'LA_T_1029621', 'A05', 'spoof']
# In parse
# flac LA_T_3358436 A04 spoof
#
# ['flac', 'LA_T_3358436', 'A04', 'spoof']
# In parse
# flac LA_T_9176704 A01 spoof
#
# ['flac', 'LA_T_9176704', 'A01', 'spoof']
# In parse
# flac LA_T_1502294 A01 spoof
#
# ['flac', 'LA_T_1502294', 'A01', 'spoof']
# In parse
# flac LA_T_6598380 A04 spoof
#
# ['flac', 'LA_T_6598380', 'A04', 'spoof']
# In parse
# flac LA_T_2925606 A05 spoof
#
# ['flac', 'LA_T_2925606', 'A05', 'spoof']
# In parse
# flac LA_T_8503702 A04 spoof
#
# ['flac', 'LA_T_8503702', 'A04', 'spoof']
# In parse
# flac LA_T_3073041 A02 spoof
#
# ['flac', 'LA_T_3073041', 'A02', 'spoof']
# In parse
# flac LA_T_3986222 A01 spoof
#
# ['flac', 'LA_T_3986222', 'A01', 'spoof']
# In parse
# flac LA_T_2037741 A02 spoof
#
# ['flac', 'LA_T_2037741', 'A02', 'spoof']
# In parse
# flac LA_T_7917052 A06 spoof
#
# ['flac', 'LA_T_7917052', 'A06', 'spoof']
# In parse
# flac LA_T_6808563 A06 spoof
#
# ['flac', 'LA_T_6808563', 'A06', 'spoof']
# In parse
# flac LA_T_4939879 A06 spoof
#
# ['flac', 'LA_T_4939879', 'A06', 'spoof']
# In parse
# flac LA_T_6492127 A05 spoof
#
# ['flac', 'LA_T_6492127', 'A05', 'spoof']
# In parse
# flac LA_T_4214756 A02 spoof
#
# ['flac', 'LA_T_4214756', 'A02', 'spoof']
# In parse
# flac LA_T_3946374 A05 spoof
#
# ['flac', 'LA_T_3946374', 'A05', 'spoof']
# In parse
# flac LA_T_5694449 A06 spoof
#
# ['flac', 'LA_T_5694449', 'A06', 'spoof']
# In parse
# flac LA_T_4358962 A02 spoof
#
# ['flac', 'LA_T_4358962', 'A02', 'spoof']
# In parse
# flac LA_T_4027861 A01 spoof
#
# ['flac', 'LA_T_4027861', 'A01', 'spoof']
# In parse
# flac LA_T_4510974 A03 spoof
#
# ['flac', 'LA_T_4510974', 'A03', 'spoof']
# In parse
# flac LA_T_6980311 A03 spoof
#
# ['flac', 'LA_T_6980311', 'A03', 'spoof']
# In parse
# flac LA_T_7548136 A02 spoof
#
# ['flac', 'LA_T_7548136', 'A02', 'spoof']
# In parse
# flac LA_T_1078605 A01 spoof
#
# ['flac', 'LA_T_1078605', 'A01', 'spoof']
# In parse
# flac LA_T_2170687 human human
#
# ['flac', 'LA_T_2170687', 'human', 'human']
# In parse
# flac LA_T_6003134 A02 spoof
#
# ['flac', 'LA_T_6003134', 'A02', 'spoof']
# In parse
# flac LA_T_8746113 A03 spoof
#
# ['flac', 'LA_T_8746113', 'A03', 'spoof']
# In parse
# flac LA_T_5815225 A02 spoof
#
# ['flac', 'LA_T_5815225', 'A02', 'spoof']
# In parse
# flac LA_T_7196997 A01 spoof
#
# ['flac', 'LA_T_7196997', 'A01', 'spoof']
# In parse
# flac LA_T_6259122 A04 spoof
#
# ['flac', 'LA_T_6259122', 'A04', 'spoof']
# In parse
# flac LA_T_4940599 A04 spoof
#
# ['flac', 'LA_T_4940599', 'A04', 'spoof']
# In parse
# flac LA_T_3873840 A02 spoof
#
# ['flac', 'LA_T_3873840', 'A02', 'spoof']
# In parse
# flac LA_T_1211236 A02 spoof
#
# ['flac', 'LA_T_1211236', 'A02', 'spoof']
# In parse
# flac LA_T_7424811 A01 spoof
#
# ['flac', 'LA_T_7424811', 'A01', 'spoof']
# In parse
# flac LA_T_6843616 A06 spoof
#
# ['flac', 'LA_T_6843616', 'A06', 'spoof']
# In parse
# flac LA_T_5583883 A05 spoof
#
# ['flac', 'LA_T_5583883', 'A05', 'spoof']
# In parse
# flac LA_T_2457740 A02 spoof
#
# ['flac', 'LA_T_2457740', 'A02', 'spoof']
# In parse
# flac LA_T_1934025 A01 spoof
#
# ['flac', 'LA_T_1934025', 'A01', 'spoof']
# In parse
# flac LA_T_4677155 A01 spoof
#
# ['flac', 'LA_T_4677155', 'A01', 'spoof']
# In parse
# flac LA_T_7913227 A03 spoof
#
# ['flac', 'LA_T_7913227', 'A03', 'spoof']
# In parse
# flac LA_T_7402461 human human
#
# ['flac', 'LA_T_7402461', 'human', 'human']
# In parse
# flac LA_T_1360535 A01 spoof
#
# ['flac', 'LA_T_1360535', 'A01', 'spoof']
# In parse
# flac LA_T_7634678 A02 spoof
#
# ['flac', 'LA_T_7634678', 'A02', 'spoof']
# In parse
# flac LA_T_1846342 human human
#
# ['flac', 'LA_T_1846342', 'human', 'human']
# In parse
# flac LA_T_5271380 A01 spoof
#
# ['flac', 'LA_T_5271380', 'A01', 'spoof']
# In parse
# flac LA_T_4492237 A02 spoof
#
# ['flac', 'LA_T_4492237', 'A02', 'spoof']
# In parse
# flac LA_T_9482120 A05 spoof
#
# ['flac', 'LA_T_9482120', 'A05', 'spoof']
# In parse
# flac LA_T_7962876 A05 spoof
#
# ['flac', 'LA_T_7962876', 'A05', 'spoof']
# In parse
# flac LA_T_4230020 A03 spoof
#
# ['flac', 'LA_T_4230020', 'A03', 'spoof']
# In parse
# flac LA_T_3477694 human human
#
# ['flac', 'LA_T_3477694', 'human', 'human']
# In parse
# flac LA_T_2147889 A01 spoof
#
# ['flac', 'LA_T_2147889', 'A01', 'spoof']
# In parse
# flac LA_T_1052701 human human
#
# ['flac', 'LA_T_1052701', 'human', 'human']
# In parse
# flac LA_T_2297639 A04 spoof
#
# ['flac', 'LA_T_2297639', 'A04', 'spoof']
# In parse
# flac LA_T_7980617 A05 spoof
#
# ['flac', 'LA_T_7980617', 'A05', 'spoof']
# In parse
# flac LA_T_8864013 A03 spoof
#
# ['flac', 'LA_T_8864013', 'A03', 'spoof']
# In parse
# flac LA_T_2389733 A05 spoof
#
# ['flac', 'LA_T_2389733', 'A05', 'spoof']
# In parse
# flac LA_T_6067007 A03 spoof
#
# ['flac', 'LA_T_6067007', 'A03', 'spoof']
# In parse
# flac LA_T_6665076 A05 spoof
#
# ['flac', 'LA_T_6665076', 'A05', 'spoof']
# In parse
# flac LA_T_3850846 A06 spoof
#
# ['flac', 'LA_T_3850846', 'A06', 'spoof']
# In parse
# flac LA_T_8697779 A03 spoof
#
# ['flac', 'LA_T_8697779', 'A03', 'spoof']
# In parse
# flac LA_T_4063249 A04 spoof
#
# ['flac', 'LA_T_4063249', 'A04', 'spoof']
# In parse
# flac LA_T_3398232 A02 spoof
#
# ['flac', 'LA_T_3398232', 'A02', 'spoof']
# In parse
# flac LA_T_2257021 A05 spoof
#
# ['flac', 'LA_T_2257021', 'A05', 'spoof']
# In parse
# flac LA_T_2435826 human human
#
# ['flac', 'LA_T_2435826', 'human', 'human']
# In parse
# flac LA_T_1870365 A03 spoof
#
# ['flac', 'LA_T_1870365', 'A03', 'spoof']
# In parse
# flac LA_T_2416931 A03 spoof
#
# ['flac', 'LA_T_2416931', 'A03', 'spoof']
# In parse
# flac LA_T_2189841 A04 spoof
#
# ['flac', 'LA_T_2189841', 'A04', 'spoof']
# In parse
# flac LA_T_1905516 A05 spoof
#
# ['flac', 'LA_T_1905516', 'A05', 'spoof']
# In parse
# flac LA_T_6379934 A04 spoof
#
# ['flac', 'LA_T_6379934', 'A04', 'spoof']
# In parse
# flac LA_T_4432519 A01 spoof
#
# ['flac', 'LA_T_4432519', 'A01', 'spoof']
# In parse
# flac LA_T_1696010 A05 spoof
#
# ['flac', 'LA_T_1696010', 'A05', 'spoof']
# In parse
# flac LA_T_1572233 A05 spoof
#
# ['flac', 'LA_T_1572233', 'A05', 'spoof']
# In parse
# flac LA_T_2438741 A04 spoof
#
# ['flac', 'LA_T_2438741', 'A04', 'spoof']
# In parse
# flac LA_T_5785000 A05 spoof
#
# ['flac', 'LA_T_5785000', 'A05', 'spoof']
# In parse
# flac LA_T_9437384 human human
#
# ['flac', 'LA_T_9437384', 'human', 'human']
# In parse
# flac LA_T_8047196 A03 spoof
#
# ['flac', 'LA_T_8047196', 'A03', 'spoof']
# In parse
# flac LA_T_1041400 A02 spoof
#
# ['flac', 'LA_T_1041400', 'A02', 'spoof']
# In parse
# flac LA_T_1026727 A01 spoof
#
# ['flac', 'LA_T_1026727', 'A01', 'spoof']
# In parse
# flac LA_T_5588242 A05 spoof
#
# ['flac', 'LA_T_5588242', 'A05', 'spoof']
# In parse
# flac LA_T_6130940 A03 spoof
#
# ['flac', 'LA_T_6130940', 'A03', 'spoof']
# In parse
# flac LA_T_4882930 A06 spoof
#
# ['flac', 'LA_T_4882930', 'A06', 'spoof']
# In parse
# flac LA_T_3746932 A01 spoof
#
# ['flac', 'LA_T_3746932', 'A01', 'spoof']
# In parse
# flac LA_T_2556228 A06 spoof
#
# ['flac', 'LA_T_2556228', 'A06', 'spoof']
# In parse
# flac LA_T_2615541 A03 spoof
#
# ['flac', 'LA_T_2615541', 'A03', 'spoof']
# In parse
# flac LA_T_7093149 A01 spoof
#
# ['flac', 'LA_T_7093149', 'A01', 'spoof']
# In parse
# flac LA_T_5947008 A06 spoof
#
# ['flac', 'LA_T_5947008', 'A06', 'spoof']
# In parse
# flac LA_T_5301501 A05 spoof
#
# ['flac', 'LA_T_5301501', 'A05', 'spoof']
# In parse
# flac LA_T_1698884 A03 spoof
#
# ['flac', 'LA_T_1698884', 'A03', 'spoof']
# In parse
# flac LA_T_8461963 human human
#
# ['flac', 'LA_T_8461963', 'human', 'human']
# In parse
# flac LA_T_7335381 A03 spoof
#
# ['flac', 'LA_T_7335381', 'A03', 'spoof']
# In parse
# flac LA_T_5107714 A02 spoof
#
# ['flac', 'LA_T_5107714', 'A02', 'spoof']
# In parse
# flac LA_T_1498247 human human
#
# ['flac', 'LA_T_1498247', 'human', 'human']
# In parse
# flac LA_T_1012129 A05 spoof
#
# ['flac', 'LA_T_1012129', 'A05', 'spoof']
# In parse
# flac LA_T_8817709 A06 spoof
#
# ['flac', 'LA_T_8817709', 'A06', 'spoof']
# In parse
# flac LA_T_1457244 A02 spoof
#
# ['flac', 'LA_T_1457244', 'A02', 'spoof']
# In parse
# flac LA_T_3434132 A01 spoof
#
# ['flac', 'LA_T_3434132', 'A01', 'spoof']
# In parse
# flac LA_T_5278239 human human
#
# ['flac', 'LA_T_5278239', 'human', 'human']
# In parse
# flac LA_T_6651562 A01 spoof
#
# ['flac', 'LA_T_6651562', 'A01', 'spoof']
# In parse
# flac LA_T_7067883 A03 spoof
#
# ['flac', 'LA_T_7067883', 'A03', 'spoof']
# In parse
# flac LA_T_8545885 human human
#
# ['flac', 'LA_T_8545885', 'human', 'human']
# In parse
# flac LA_T_5390095 A04 spoof
#
# ['flac', 'LA_T_5390095', 'A04', 'spoof']
# In parse
# flac LA_T_5828832 A01 spoof
#
# ['flac', 'LA_T_5828832', 'A01', 'spoof']
# In parse
# flac LA_T_3775779 A04 spoof
#
# ['flac', 'LA_T_3775779', 'A04', 'spoof']
# In parse
# flac LA_T_7539575 A02 spoof
#
# ['flac', 'LA_T_7539575', 'A02', 'spoof']
# In parse
# flac LA_T_7056372 A01 spoof
#
# ['flac', 'LA_T_7056372', 'A01', 'spoof']
# In parse
# flac LA_T_3579475 A04 spoof
#
# ['flac', 'LA_T_3579475', 'A04', 'spoof']
# In parse
# flac LA_T_4403320 human human
#
# ['flac', 'LA_T_4403320', 'human', 'human']
# In parse
# flac LA_T_9469344 A05 spoof
#
# ['flac', 'LA_T_9469344', 'A05', 'spoof']
# In parse
# flac LA_T_1406306 A03 spoof
#
# ['flac', 'LA_T_1406306', 'A03', 'spoof']
# In parse
# flac LA_T_4472122 A03 spoof
#
# ['flac', 'LA_T_4472122', 'A03', 'spoof']
# In parse
# flac LA_T_5879219 human human
#
# ['flac', 'LA_T_5879219', 'human', 'human']
# In parse
# flac LA_T_3244623 A03 spoof
#
# ['flac', 'LA_T_3244623', 'A03', 'spoof']
# In parse
# flac LA_T_7656347 A04 spoof
#
# ['flac', 'LA_T_7656347', 'A04', 'spoof']
# In parse
# flac LA_T_7368890 A04 spoof
#
# ['flac', 'LA_T_7368890', 'A04', 'spoof']
# In parse
# flac LA_T_9432524 A05 spoof
#
# ['flac', 'LA_T_9432524', 'A05', 'spoof']
# In parse
# flac LA_T_4896745 A05 spoof
#
# ['flac', 'LA_T_4896745', 'A05', 'spoof']
# In parse
# flac LA_T_5891775 human human
#
# ['flac', 'LA_T_5891775', 'human', 'human']
# In parse
# flac LA_T_4527427 A03 spoof
#
# ['flac', 'LA_T_4527427', 'A03', 'spoof']
# In parse
# flac LA_T_1506330 A01 spoof
#
# ['flac', 'LA_T_1506330', 'A01', 'spoof']
# In parse
# flac LA_T_4914312 A06 spoof
#
# ['flac', 'LA_T_4914312', 'A06', 'spoof']
# In parse
# flac LA_T_4588024 A04 spoof
#
# ['flac', 'LA_T_4588024', 'A04', 'spoof']
# In parse
# flac LA_T_6834976 A03 spoof
#
# ['flac', 'LA_T_6834976', 'A03', 'spoof']
# In parse
# flac LA_T_3546489 A06 spoof
#
# ['flac', 'LA_T_3546489', 'A06', 'spoof']
# In parse
# flac LA_T_4822766 human human
#
# ['flac', 'LA_T_4822766', 'human', 'human']
# In parse
# flac LA_T_5288433 A06 spoof
#
# ['flac', 'LA_T_5288433', 'A06', 'spoof']
# In parse
# flac LA_T_7662280 A06 spoof
#
# ['flac', 'LA_T_7662280', 'A06', 'spoof']
# In parse
# flac LA_T_7126643 A06 spoof
#
# ['flac', 'LA_T_7126643', 'A06', 'spoof']
# In parse
# flac LA_T_5754252 A06 spoof
#
# ['flac', 'LA_T_5754252', 'A06', 'spoof']
# In parse
# flac LA_T_5966872 A03 spoof
#
# ['flac', 'LA_T_5966872', 'A03', 'spoof']
# In parse
# flac LA_T_6093520 human human
#
# ['flac', 'LA_T_6093520', 'human', 'human']
# In parse
# flac LA_T_7182698 A01 spoof
#
# ['flac', 'LA_T_7182698', 'A01', 'spoof']
# In parse
# flac LA_T_4675650 A04 spoof
#
# ['flac', 'LA_T_4675650', 'A04', 'spoof']
# In parse
# flac LA_T_6413896 A03 spoof
#
# ['flac', 'LA_T_6413896', 'A03', 'spoof']
# In parse
# flac LA_T_4997954 A04 spoof
#
# ['flac', 'LA_T_4997954', 'A04', 'spoof']
# In parse
# flac LA_T_2307815 human human
#
# ['flac', 'LA_T_2307815', 'human', 'human']
# In parse
# flac LA_T_8328490 A02 spoof
#
# ['flac', 'LA_T_8328490', 'A02', 'spoof']
# In parse
# flac LA_T_2155869 A06 spoof
#
# ['flac', 'LA_T_2155869', 'A06', 'spoof']
# In parse
# flac LA_T_4999485 A04 spoof
#
# ['flac', 'LA_T_4999485', 'A04', 'spoof']
# In parse
# flac LA_T_6138991 A04 spoof
#
# ['flac', 'LA_T_6138991', 'A04', 'spoof']
# In parse
# flac LA_T_4975139 A03 spoof
#
# ['flac', 'LA_T_4975139', 'A03', 'spoof']
# In parse
# flac LA_T_2774875 human human
#
# ['flac', 'LA_T_2774875', 'human', 'human']
# In parse
# flac LA_T_9082929 A03 spoof
#
# ['flac', 'LA_T_9082929', 'A03', 'spoof']
# In parse
# flac LA_T_7112968 A05 spoof
#
# ['flac', 'LA_T_7112968', 'A05', 'spoof']
# In parse
# flac LA_T_4314190 A05 spoof
#
# ['flac', 'LA_T_4314190', 'A05', 'spoof']
# In parse
# flac LA_T_4636610 A05 spoof
#
# ['flac', 'LA_T_4636610', 'A05', 'spoof']
# In parse
# flac LA_T_5184475 A04 spoof
#
# ['flac', 'LA_T_5184475', 'A04', 'spoof']
# In parse
# flac LA_T_3896254 A06 spoof
#
# ['flac', 'LA_T_3896254', 'A06', 'spoof']
# In parse
# flac LA_T_2904734 A03 spoof
#
# ['flac', 'LA_T_2904734', 'A03', 'spoof']
# In parse
# flac LA_T_3778918 A05 spoof
#
# ['flac', 'LA_T_3778918', 'A05', 'spoof']
# In parse
# flac LA_T_7440362 A06 spoof
#
# ['flac', 'LA_T_7440362', 'A06', 'spoof']
# In parse
# flac LA_T_8437284 A05 spoof
#
# ['flac', 'LA_T_8437284', 'A05', 'spoof']
# In parse
# flac LA_T_4948068 A01 spoof
#
# ['flac', 'LA_T_4948068', 'A01', 'spoof']
# In parse
# flac LA_T_7984161 A05 spoof
#
# ['flac', 'LA_T_7984161', 'A05', 'spoof']
# In parse
# flac LA_T_2439963 A05 spoof
#
# ['flac', 'LA_T_2439963', 'A05', 'spoof']
# In parse
# flac LA_T_2061511 A01 spoof
#
# ['flac', 'LA_T_2061511', 'A01', 'spoof']
# In parse
# flac LA_T_4878362 A05 spoof
#
# ['flac', 'LA_T_4878362', 'A05', 'spoof']
# In parse
# flac LA_T_8356880 A01 spoof
#
# ['flac', 'LA_T_8356880', 'A01', 'spoof']
# In parse
# flac LA_T_9628969 A02 spoof
#
# ['flac', 'LA_T_9628969', 'A02', 'spoof']
# In parse
# flac LA_T_9817584 A02 spoof
#
# ['flac', 'LA_T_9817584', 'A02', 'spoof']
# In parse
# flac LA_T_5623910 A02 spoof
#
# ['flac', 'LA_T_5623910', 'A02', 'spoof']
# In parse
# flac LA_T_9897496 A05 spoof
#
# ['flac', 'LA_T_9897496', 'A05', 'spoof']
# In parse
# flac LA_T_8883534 A06 spoof
#
# ['flac', 'LA_T_8883534', 'A06', 'spoof']
# In parse
# flac LA_T_3420154 A05 spoof
#
# ['flac', 'LA_T_3420154', 'A05', 'spoof']
# In parse
# flac LA_T_3266022 human human
#
# ['flac', 'LA_T_3266022', 'human', 'human']
# In parse
# flac LA_T_2579817 A03 spoof
#
# ['flac', 'LA_T_2579817', 'A03', 'spoof']
# In parse
# flac LA_T_8206162 A05 spoof
#
# ['flac', 'LA_T_8206162', 'A05', 'spoof']
# In parse
# flac LA_T_5688836 A01 spoof
#
# ['flac', 'LA_T_5688836', 'A01', 'spoof']
# In parse
# flac LA_T_3615583 A03 spoof
#
# ['flac', 'LA_T_3615583', 'A03', 'spoof']
# In parse
# flac LA_T_2428785 A05 spoof
#
# ['flac', 'LA_T_2428785', 'A05', 'spoof']
# In parse
# flac LA_T_2909089 A02 spoof
#
# ['flac', 'LA_T_2909089', 'A02', 'spoof']
# In parse
# flac LA_T_8094753 A04 spoof
#
# ['flac', 'LA_T_8094753', 'A04', 'spoof']
# In parse
# flac LA_T_4901673 A01 spoof
#
# ['flac', 'LA_T_4901673', 'A01', 'spoof']
# In parse
# flac LA_T_7764970 A03 spoof
#
# ['flac', 'LA_T_7764970', 'A03', 'spoof']
# In parse
# flac LA_T_4161242 A04 spoof
#
# ['flac', 'LA_T_4161242', 'A04', 'spoof']
# In parse
# flac LA_T_9889764 A06 spoof
#
# ['flac', 'LA_T_9889764', 'A06', 'spoof']
# In parse
# flac LA_T_4868092 A02 spoof
#
# ['flac', 'LA_T_4868092', 'A02', 'spoof']
# In parse
# flac LA_T_4184109 A04 spoof
#
# ['flac', 'LA_T_4184109', 'A04', 'spoof']
# In parse
# flac LA_T_7918894 A04 spoof
#
# ['flac', 'LA_T_7918894', 'A04', 'spoof']
# In parse
# flac LA_T_1341815 A05 spoof
#
# ['flac', 'LA_T_1341815', 'A05', 'spoof']
# In parse
# flac LA_T_5145803 A01 spoof
#
# ['flac', 'LA_T_5145803', 'A01', 'spoof']
# In parse
# flac LA_T_4048311 A02 spoof
#
# ['flac', 'LA_T_4048311', 'A02', 'spoof']
# In parse
# flac LA_T_9355786 A03 spoof
#
# ['flac', 'LA_T_9355786', 'A03', 'spoof']
# In parse
# flac LA_T_5692441 A05 spoof
#
# ['flac', 'LA_T_5692441', 'A05', 'spoof']
# In parse
# flac LA_T_7959815 A03 spoof
#
# ['flac', 'LA_T_7959815', 'A03', 'spoof']
# In parse
# flac LA_T_6353583 A04 spoof
#
# ['flac', 'LA_T_6353583', 'A04', 'spoof']
# In parse
# flac LA_T_2005149 A02 spoof
#
# ['flac', 'LA_T_2005149', 'A02', 'spoof']
# In parse
# flac LA_T_1365222 A05 spoof
#
# ['flac', 'LA_T_1365222', 'A05', 'spoof']
# In parse
# flac LA_T_9301195 A04 spoof
#
# ['flac', 'LA_T_9301195', 'A04', 'spoof']
# In parse
# flac LA_T_3659915 human human
#
# ['flac', 'LA_T_3659915', 'human', 'human']
# In parse
# flac LA_T_8514622 A04 spoof
#
# ['flac', 'LA_T_8514622', 'A04', 'spoof']
# In parse
# flac LA_T_8850640 A05 spoof
#
# ['flac', 'LA_T_8850640', 'A05', 'spoof']
# In parse
# flac LA_T_9850386 A06 spoof
#
# ['flac', 'LA_T_9850386', 'A06', 'spoof']
# In parse
# flac LA_T_7365102 A04 spoof
#
# ['flac', 'LA_T_7365102', 'A04', 'spoof']
# In parse
# flac LA_T_4387053 A01 spoof
#
# ['flac', 'LA_T_4387053', 'A01', 'spoof']
# In parse
# flac LA_T_1130893 A05 spoof
#
# ['flac', 'LA_T_1130893', 'A05', 'spoof']
# In parse
# flac LA_T_5919466 A05 spoof
#
# ['flac', 'LA_T_5919466', 'A05', 'spoof']
# In parse
# flac LA_T_7220142 A05 spoof
#
# ['flac', 'LA_T_7220142', 'A05', 'spoof']
# In parse
# flac LA_T_3990600 A02 spoof
#
# ['flac', 'LA_T_3990600', 'A02', 'spoof']
# In parse
# flac LA_T_2964450 A05 spoof
#
# ['flac', 'LA_T_2964450', 'A05', 'spoof']
# In parse
# flac LA_T_3965671 A01 spoof
#
# ['flac', 'LA_T_3965671', 'A01', 'spoof']
# In parse
# flac LA_T_7228186 A05 spoof
#
# ['flac', 'LA_T_7228186', 'A05', 'spoof']
# In parse
# flac LA_T_8458654 human human
#
# ['flac', 'LA_T_8458654', 'human', 'human']
# In parse
# flac LA_T_8912726 A03 spoof
#
# ['flac', 'LA_T_8912726', 'A03', 'spoof']
# In parse
# flac LA_T_5995788 A03 spoof
#
# ['flac', 'LA_T_5995788', 'A03', 'spoof']
# In parse
# flac LA_T_4155790 A04 spoof
#
# ['flac', 'LA_T_4155790', 'A04', 'spoof']
# In parse
# flac LA_T_1703395 human human
#
# ['flac', 'LA_T_1703395', 'human', 'human']
# In parse
# flac LA_T_3264613 human human
#
# ['flac', 'LA_T_3264613', 'human', 'human']
# In parse
# flac LA_T_1108702 A03 spoof
#
# ['flac', 'LA_T_1108702', 'A03', 'spoof']
# In parse
# flac LA_T_1610459 A02 spoof
#
# ['flac', 'LA_T_1610459', 'A02', 'spoof']
# In parse
# flac LA_T_1294228 A04 spoof
#
# ['flac', 'LA_T_1294228', 'A04', 'spoof']
# In parse
# flac LA_T_5133745 A06 spoof
#
# ['flac', 'LA_T_5133745', 'A06', 'spoof']
# In parse
# flac LA_T_3024331 A04 spoof
#
# ['flac', 'LA_T_3024331', 'A04', 'spoof']
# In parse
# flac LA_T_9167410 A05 spoof
#
# ['flac', 'LA_T_9167410', 'A05', 'spoof']
# In parse
# flac LA_T_1033197 A06 spoof
#
# ['flac', 'LA_T_1033197', 'A06', 'spoof']
# In parse
# flac LA_T_1798127 A03 spoof
#
# ['flac', 'LA_T_1798127', 'A03', 'spoof']
# In parse
# flac LA_T_2388783 human human
#
# ['flac', 'LA_T_2388783', 'human', 'human']
# In parse
# flac LA_T_9668313 A04 spoof
#
# ['flac', 'LA_T_9668313', 'A04', 'spoof']
# In parse
# flac LA_T_6394093 A02 spoof
#
# ['flac', 'LA_T_6394093', 'A02', 'spoof']
# In parse
# flac LA_T_8175934 A03 spoof
#
# ['flac', 'LA_T_8175934', 'A03', 'spoof']
# In parse
# flac LA_T_2191248 A05 spoof
#
# ['flac', 'LA_T_2191248', 'A05', 'spoof']
# In parse
# flac LA_T_3185009 A02 spoof
#
# ['flac', 'LA_T_3185009', 'A02', 'spoof']
# In parse
# flac LA_T_4010884 A02 spoof
#
# ['flac', 'LA_T_4010884', 'A02', 'spoof']
# In parse
# flac LA_T_7742722 A04 spoof
#
# ['flac', 'LA_T_7742722', 'A04', 'spoof']
# In parse
# flac LA_T_8379318 A05 spoof
#
# ['flac', 'LA_T_8379318', 'A05', 'spoof']
# In parse
# flac LA_T_1392859 A04 spoof
#
# ['flac', 'LA_T_1392859', 'A04', 'spoof']
# In parse
# flac LA_T_7446731 A02 spoof
#
# ['flac', 'LA_T_7446731', 'A02', 'spoof']
# In parse
# flac LA_T_6511702 A05 spoof
#
# ['flac', 'LA_T_6511702', 'A05', 'spoof']
# In parse
# flac LA_T_4590373 A04 spoof
#
# ['flac', 'LA_T_4590373', 'A04', 'spoof']
# In parse
# flac LA_T_7766390 A06 spoof
#
# ['flac', 'LA_T_7766390', 'A06', 'spoof']
# In parse
# flac LA_T_2864869 A04 spoof
#
# ['flac', 'LA_T_2864869', 'A04', 'spoof']
# In parse
# flac LA_T_4366653 A04 spoof
#
# ['flac', 'LA_T_4366653', 'A04', 'spoof']
# In parse
# flac LA_T_4124430 human human
#
# ['flac', 'LA_T_4124430', 'human', 'human']
# In parse
# flac LA_T_5296903 A06 spoof
#
# ['flac', 'LA_T_5296903', 'A06', 'spoof']
# In parse
# flac LA_T_4008513 A01 spoof
#
# ['flac', 'LA_T_4008513', 'A01', 'spoof']
# In parse
# flac LA_T_9373039 A05 spoof
#
# ['flac', 'LA_T_9373039', 'A05', 'spoof']
# In parse
# flac LA_T_9373284 A04 spoof
#
# ['flac', 'LA_T_9373284', 'A04', 'spoof']
# In parse
# flac LA_T_3461158 A04 spoof
#
# ['flac', 'LA_T_3461158', 'A04', 'spoof']
# In parse
# flac LA_T_4848180 human human
#
# ['flac', 'LA_T_4848180', 'human', 'human']
# In parse
# flac LA_T_2018143 A05 spoof
#
# ['flac', 'LA_T_2018143', 'A05', 'spoof']
# In parse
# flac LA_T_9633918 A04 spoof
#
# ['flac', 'LA_T_9633918', 'A04', 'spoof']
# In parse
# flac LA_T_3314192 human human
#
# ['flac', 'LA_T_3314192', 'human', 'human']
# In parse
# flac LA_T_2117042 A03 spoof
#
# ['flac', 'LA_T_2117042', 'A03', 'spoof']
# In parse
# flac LA_T_4121032 A02 spoof
#
# ['flac', 'LA_T_4121032', 'A02', 'spoof']
# In parse
# flac LA_T_7121562 A01 spoof
#
# ['flac', 'LA_T_7121562', 'A01', 'spoof']
# In parse
# flac LA_T_7070603 A06 spoof
#
# ['flac', 'LA_T_7070603', 'A06', 'spoof']
# In parse
# flac LA_T_8504043 A04 spoof
#
# ['flac', 'LA_T_8504043', 'A04', 'spoof']
# In parse
# flac LA_T_6085814 A02 spoof
#
# ['flac', 'LA_T_6085814', 'A02', 'spoof']
# In parse
# flac LA_T_4630773 A04 spoof
#
# ['flac', 'LA_T_4630773', 'A04', 'spoof']
# In parse
# flac LA_T_6970113 human human
#
# ['flac', 'LA_T_6970113', 'human', 'human']
# In parse
# flac LA_T_7778575 human human
#
# ['flac', 'LA_T_7778575', 'human', 'human']
# In parse
# flac LA_T_6377566 A04 spoof
#
# ['flac', 'LA_T_6377566', 'A04', 'spoof']
# In parse
# flac LA_T_4982096 A04 spoof
#
# ['flac', 'LA_T_4982096', 'A04', 'spoof']
# In parse
# flac LA_T_8047375 A01 spoof
#
# ['flac', 'LA_T_8047375', 'A01', 'spoof']
# In parse
# flac LA_T_2859018 A01 spoof
#
# ['flac', 'LA_T_2859018', 'A01', 'spoof']
# In parse
# flac LA_T_8491412 A05 spoof
#
# ['flac', 'LA_T_8491412', 'A05', 'spoof']
# In parse
# flac LA_T_2607360 A02 spoof
#
# ['flac', 'LA_T_2607360', 'A02', 'spoof']
# In parse
# flac LA_T_6181547 A04 spoof
#
# ['flac', 'LA_T_6181547', 'A04', 'spoof']
# In parse
# flac LA_T_2076344 A02 spoof
#
# ['flac', 'LA_T_2076344', 'A02', 'spoof']
# In parse
# flac LA_T_6754577 A05 spoof
#
# ['flac', 'LA_T_6754577', 'A05', 'spoof']
# In parse
# flac LA_T_8312754 A02 spoof
#
# ['flac', 'LA_T_8312754', 'A02', 'spoof']
# In parse
# flac LA_T_5639932 A02 spoof
#
# ['flac', 'LA_T_5639932', 'A02', 'spoof']
# In parse
# flac LA_T_4242513 A01 spoof
#
# ['flac', 'LA_T_4242513', 'A01', 'spoof']
# In parse
# flac LA_T_9104141 A01 spoof
#
# ['flac', 'LA_T_9104141', 'A01', 'spoof']
# In parse
# flac LA_T_1861400 A02 spoof
#
# ['flac', 'LA_T_1861400', 'A02', 'spoof']
# In parse
# flac LA_T_5663225 A06 spoof
#
# ['flac', 'LA_T_5663225', 'A06', 'spoof']
# In parse
# flac LA_T_7880203 A01 spoof
#
# ['flac', 'LA_T_7880203', 'A01', 'spoof']
# In parse
# flac LA_T_1398292 A01 spoof
#
# ['flac', 'LA_T_1398292', 'A01', 'spoof']
# In parse
# flac LA_T_1673143 A06 spoof
#
# ['flac', 'LA_T_1673143', 'A06', 'spoof']
# In parse
# flac LA_T_9480596 A04 spoof
#
# ['flac', 'LA_T_9480596', 'A04', 'spoof']
# In parse
# flac LA_T_1121656 A03 spoof
#
# ['flac', 'LA_T_1121656', 'A03', 'spoof']
# In parse
# flac LA_T_8075385 A04 spoof
#
# ['flac', 'LA_T_8075385', 'A04', 'spoof']
# In parse
# flac LA_T_7550620 A05 spoof
#
# ['flac', 'LA_T_7550620', 'A05', 'spoof']
# In parse
# flac LA_T_3773782 A02 spoof
#
# ['flac', 'LA_T_3773782', 'A02', 'spoof']
# In parse
# flac LA_T_5132627 A05 spoof
#
# ['flac', 'LA_T_5132627', 'A05', 'spoof']
# In parse
# flac LA_T_4063190 A03 spoof
#
# ['flac', 'LA_T_4063190', 'A03', 'spoof']
# In parse
# flac LA_T_2888441 A02 spoof
#
# ['flac', 'LA_T_2888441', 'A02', 'spoof']
# In parse
# flac LA_T_5085674 A02 spoof
#
# ['flac', 'LA_T_5085674', 'A02', 'spoof']
# In parse
# flac LA_T_3467896 A06 spoof
#
# ['flac', 'LA_T_3467896', 'A06', 'spoof']
# In parse
# flac LA_T_5091732 A02 spoof
#
# ['flac', 'LA_T_5091732', 'A02', 'spoof']
# In parse
# flac LA_T_3339131 A03 spoof
#
# ['flac', 'LA_T_3339131', 'A03', 'spoof']
# In parse
# flac LA_T_4303697 A06 spoof
#
# ['flac', 'LA_T_4303697', 'A06', 'spoof']
# In parse
# flac LA_T_2073846 A03 spoof
#
# ['flac', 'LA_T_2073846', 'A03', 'spoof']
# In parse
# flac LA_T_9827450 A01 spoof
#
# ['flac', 'LA_T_9827450', 'A01', 'spoof']
# In parse
# flac LA_T_9667089 human human
#
# ['flac', 'LA_T_9667089', 'human', 'human']
# In parse
# flac LA_T_7770182 A05 spoof
#
# ['flac', 'LA_T_7770182', 'A05', 'spoof']
# In parse
# flac LA_T_6636159 human human
#
# ['flac', 'LA_T_6636159', 'human', 'human']
# In parse
# flac LA_T_6439734 A01 spoof
#
# ['flac', 'LA_T_6439734', 'A01', 'spoof']
# In parse
# flac LA_T_3650320 A03 spoof
#
# ['flac', 'LA_T_3650320', 'A03', 'spoof']
# In parse
# flac LA_T_1414804 A04 spoof
#
# ['flac', 'LA_T_1414804', 'A04', 'spoof']
# In parse
# flac LA_T_7459552 A06 spoof
#
# ['flac', 'LA_T_7459552', 'A06', 'spoof']
# In parse
# flac LA_T_1746987 human human
#
# ['flac', 'LA_T_1746987', 'human', 'human']
# In parse
# flac LA_T_3033308 A04 spoof
#
# ['flac', 'LA_T_3033308', 'A04', 'spoof']
# In parse
# flac LA_T_8125315 A04 spoof
#
# ['flac', 'LA_T_8125315', 'A04', 'spoof']
# In parse
# flac LA_T_7892557 A04 spoof
#
# ['flac', 'LA_T_7892557', 'A04', 'spoof']
# In parse
# flac LA_T_8772123 A01 spoof
#
# ['flac', 'LA_T_8772123', 'A01', 'spoof']
# In parse
# flac LA_T_2046789 A02 spoof
#
# ['flac', 'LA_T_2046789', 'A02', 'spoof']
# In parse
# flac LA_T_6426017 human human
#
# ['flac', 'LA_T_6426017', 'human', 'human']
# In parse
# flac LA_T_7232286 A03 spoof
#
# ['flac', 'LA_T_7232286', 'A03', 'spoof']
# In parse
# flac LA_T_9812437 A04 spoof
#
# ['flac', 'LA_T_9812437', 'A04', 'spoof']
# In parse
# flac LA_T_9784585 human human
#
# ['flac', 'LA_T_9784585', 'human', 'human']
# In parse
# flac LA_T_1149087 A04 spoof
#
# ['flac', 'LA_T_1149087', 'A04', 'spoof']
# In parse
# flac LA_T_9413366 A06 spoof
#
# ['flac', 'LA_T_9413366', 'A06', 'spoof']
# In parse
# flac LA_T_7608702 A01 spoof
#
# ['flac', 'LA_T_7608702', 'A01', 'spoof']
# In parse
# flac LA_T_7665189 A01 spoof
#
# ['flac', 'LA_T_7665189', 'A01', 'spoof']
# In parse
# flac LA_T_3369393 A02 spoof
#
# ['flac', 'LA_T_3369393', 'A02', 'spoof']
# In parse
# flac LA_T_1546085 A05 spoof
#
# ['flac', 'LA_T_1546085', 'A05', 'spoof']
# In parse
# flac LA_T_5807714 A06 spoof
#
# ['flac', 'LA_T_5807714', 'A06', 'spoof']
# In parse
# flac LA_T_6879992 A04 spoof
#
# ['flac', 'LA_T_6879992', 'A04', 'spoof']
# In parse
# flac LA_T_6522195 A03 spoof
#
# ['flac', 'LA_T_6522195', 'A03', 'spoof']
# In parse
# flac LA_T_4946883 A04 spoof
#
# ['flac', 'LA_T_4946883', 'A04', 'spoof']
# In parse
# flac LA_T_7456957 A05 spoof
#
# ['flac', 'LA_T_7456957', 'A05', 'spoof']
# In parse
# flac LA_T_7813750 A02 spoof
#
# ['flac', 'LA_T_7813750', 'A02', 'spoof']
# In parse
# flac LA_T_9762622 A05 spoof
#
# ['flac', 'LA_T_9762622', 'A05', 'spoof']
# In parse
# flac LA_T_3201480 A05 spoof
#
# ['flac', 'LA_T_3201480', 'A05', 'spoof']
# In parse
# flac LA_T_6107013 A05 spoof
#
# ['flac', 'LA_T_6107013', 'A05', 'spoof']
# In parse
# flac LA_T_3877376 A04 spoof
#
# ['flac', 'LA_T_3877376', 'A04', 'spoof']
# In parse
# flac LA_T_6501921 A04 spoof
#
# ['flac', 'LA_T_6501921', 'A04', 'spoof']
# In parse
# flac LA_T_8830387 A04 spoof
#
# ['flac', 'LA_T_8830387', 'A04', 'spoof']
# In parse
# flac LA_T_7665257 A06 spoof
#
# ['flac', 'LA_T_7665257', 'A06', 'spoof']
# In parse
# flac LA_T_2545334 A06 spoof
#
# ['flac', 'LA_T_2545334', 'A06', 'spoof']
# In parse
# flac LA_T_3736551 A02 spoof
#
# ['flac', 'LA_T_3736551', 'A02', 'spoof']
# In parse
# flac LA_T_8129045 A04 spoof
#
# ['flac', 'LA_T_8129045', 'A04', 'spoof']
# In parse
# flac LA_T_2034492 A05 spoof
#
# ['flac', 'LA_T_2034492', 'A05', 'spoof']
# In parse
# flac LA_T_6066371 A05 spoof
#
# ['flac', 'LA_T_6066371', 'A05', 'spoof']
# In parse
# flac LA_T_9238749 A02 spoof
#
# ['flac', 'LA_T_9238749', 'A02', 'spoof']
# In parse
# flac LA_T_8149114 A02 spoof
#
# ['flac', 'LA_T_8149114', 'A02', 'spoof']
# In parse
# flac LA_T_7409426 A06 spoof
#
# ['flac', 'LA_T_7409426', 'A06', 'spoof']
# In parse
# flac LA_T_2070198 A05 spoof
#
# ['flac', 'LA_T_2070198', 'A05', 'spoof']
# In parse
# flac LA_T_8273340 human human
#
# ['flac', 'LA_T_8273340', 'human', 'human']
# In parse
# flac LA_T_7691292 A02 spoof
#
# ['flac', 'LA_T_7691292', 'A02', 'spoof']
# In parse
# flac LA_T_2236137 A06 spoof
#
# ['flac', 'LA_T_2236137', 'A06', 'spoof']
# In parse
# flac LA_T_8744965 A05 spoof
#
# ['flac', 'LA_T_8744965', 'A05', 'spoof']
# In parse
# flac LA_T_6576205 A03 spoof
#
# ['flac', 'LA_T_6576205', 'A03', 'spoof']
# In parse
# flac LA_T_2830574 A01 spoof
#
# ['flac', 'LA_T_2830574', 'A01', 'spoof']
# In parse
# flac LA_T_8895378 A06 spoof
#
# ['flac', 'LA_T_8895378', 'A06', 'spoof']
# In parse
# flac LA_T_7464577 A01 spoof
#
# ['flac', 'LA_T_7464577', 'A01', 'spoof']
# In parse
# flac LA_T_6366745 A05 spoof
#
# ['flac', 'LA_T_6366745', 'A05', 'spoof']
# In parse
# flac LA_T_9059601 A05 spoof
#
# ['flac', 'LA_T_9059601', 'A05', 'spoof']
# In parse
# flac LA_T_5812240 A01 spoof
#
# ['flac', 'LA_T_5812240', 'A01', 'spoof']
# In parse
# flac LA_T_5350696 A02 spoof
#
# ['flac', 'LA_T_5350696', 'A02', 'spoof']
# In parse
# flac LA_T_9499930 A05 spoof
#
# ['flac', 'LA_T_9499930', 'A05', 'spoof']
# In parse
# flac LA_T_6739861 A05 spoof
#
# ['flac', 'LA_T_6739861', 'A05', 'spoof']
# In parse
# flac LA_T_3861578 A06 spoof
#
# ['flac', 'LA_T_3861578', 'A06', 'spoof']
# In parse
# flac LA_T_7672686 A01 spoof
#
# ['flac', 'LA_T_7672686', 'A01', 'spoof']
# In parse
# flac LA_T_9631043 A06 spoof
#
# ['flac', 'LA_T_9631043', 'A06', 'spoof']
# In parse
# flac LA_T_8574726 A02 spoof
#
# ['flac', 'LA_T_8574726', 'A02', 'spoof']
# In parse
# flac LA_T_3589315 A03 spoof
#
# ['flac', 'LA_T_3589315', 'A03', 'spoof']
# In parse
# flac LA_T_2420983 A01 spoof
#
# ['flac', 'LA_T_2420983', 'A01', 'spoof']
# In parse
# flac LA_T_6957555 A06 spoof
#
# ['flac', 'LA_T_6957555', 'A06', 'spoof']
# In parse
# flac LA_T_5449374 A01 spoof
#
# ['flac', 'LA_T_5449374', 'A01', 'spoof']
# In parse
# flac LA_T_8388352 A03 spoof
#
# ['flac', 'LA_T_8388352', 'A03', 'spoof']
# In parse
# flac LA_T_6128016 A02 spoof
#
# ['flac', 'LA_T_6128016', 'A02', 'spoof']
# In parse
# flac LA_T_9064621 A02 spoof
#
# ['flac', 'LA_T_9064621', 'A02', 'spoof']
# In parse
# flac LA_T_1497287 A02 spoof
#
# ['flac', 'LA_T_1497287', 'A02', 'spoof']
# In parse
# flac LA_T_4772659 A01 spoof
#
# ['flac', 'LA_T_4772659', 'A01', 'spoof']
# In parse
# flac LA_T_9937666 A02 spoof
#
# ['flac', 'LA_T_9937666', 'A02', 'spoof']
# In parse
# flac LA_T_8281678 A06 spoof
#
# ['flac', 'LA_T_8281678', 'A06', 'spoof']
# In parse
# flac LA_T_4298631 A03 spoof
#
# ['flac', 'LA_T_4298631', 'A03', 'spoof']
# In parse
# flac LA_T_3848559 A02 spoof
#
# ['flac', 'LA_T_3848559', 'A02', 'spoof']
# In parse
# flac LA_T_8502627 A01 spoof
#
# ['flac', 'LA_T_8502627', 'A01', 'spoof']
# In parse
# flac LA_T_1902043 A06 spoof
#
# ['flac', 'LA_T_1902043', 'A06', 'spoof']
# In parse
# flac LA_T_9286746 A04 spoof
#
# ['flac', 'LA_T_9286746', 'A04', 'spoof']
# In parse
# flac LA_T_2815432 A04 spoof
#
# ['flac', 'LA_T_2815432', 'A04', 'spoof']
# In parse
# flac LA_T_9105169 A01 spoof
#
# ['flac', 'LA_T_9105169', 'A01', 'spoof']
# In parse
# flac LA_T_7863787 A03 spoof
#
# ['flac', 'LA_T_7863787', 'A03', 'spoof']
# In parse
# flac LA_T_1690626 A03 spoof
#
# ['flac', 'LA_T_1690626', 'A03', 'spoof']
# In parse
# flac LA_T_8646134 A04 spoof
#
# ['flac', 'LA_T_8646134', 'A04', 'spoof']
# In parse
# flac LA_T_2203140 A03 spoof
#
# ['flac', 'LA_T_2203140', 'A03', 'spoof']
# In parse
# flac LA_T_1451321 A01 spoof
#
# ['flac', 'LA_T_1451321', 'A01', 'spoof']
# In parse
# flac LA_T_1128464 A05 spoof
#
# ['flac', 'LA_T_1128464', 'A05', 'spoof']
# In parse
# flac LA_T_6011525 A03 spoof
#
# ['flac', 'LA_T_6011525', 'A03', 'spoof']
# In parse
# flac LA_T_7861937 A06 spoof
#
# ['flac', 'LA_T_7861937', 'A06', 'spoof']
# In parse
# flac LA_T_4140135 human human
#
# ['flac', 'LA_T_4140135', 'human', 'human']
# In parse
# flac LA_T_3369291 A05 spoof
#
# ['flac', 'LA_T_3369291', 'A05', 'spoof']
# In parse
# flac LA_T_4170675 A04 spoof
#
# ['flac', 'LA_T_4170675', 'A04', 'spoof']
# In parse
# flac LA_T_6750424 A06 spoof
#
# ['flac', 'LA_T_6750424', 'A06', 'spoof']
# In parse
# flac LA_T_3339881 A01 spoof
#
# ['flac', 'LA_T_3339881', 'A01', 'spoof']
# In parse
# flac LA_T_3321643 A06 spoof
#
# ['flac', 'LA_T_3321643', 'A06', 'spoof']
# In parse
# flac LA_T_5214756 A03 spoof
#
# ['flac', 'LA_T_5214756', 'A03', 'spoof']
# In parse
# flac LA_T_2838481 A05 spoof
#
# ['flac', 'LA_T_2838481', 'A05', 'spoof']
# In parse
# flac LA_T_5592527 human human
#
# ['flac', 'LA_T_5592527', 'human', 'human']
# In parse
# flac LA_T_3852630 A05 spoof
#
# ['flac', 'LA_T_3852630', 'A05', 'spoof']
# In parse
# flac LA_T_3326804 A02 spoof
#
# ['flac', 'LA_T_3326804', 'A02', 'spoof']
# In parse
# flac LA_T_4883049 A04 spoof
#
# ['flac', 'LA_T_4883049', 'A04', 'spoof']
# In parse
# flac LA_T_4662054 A03 spoof
#
# ['flac', 'LA_T_4662054', 'A03', 'spoof']
# In parse
# flac LA_T_4223032 A01 spoof
#
# ['flac', 'LA_T_4223032', 'A01', 'spoof']
# In parse
# flac LA_T_1907969 A05 spoof
#
# ['flac', 'LA_T_1907969', 'A05', 'spoof']
# In parse
# flac LA_T_8812445 human human
#
# ['flac', 'LA_T_8812445', 'human', 'human']
# In parse
# flac LA_T_1081824 A06 spoof
#
# ['flac', 'LA_T_1081824', 'A06', 'spoof']
# In parse
# flac LA_T_1473155 A01 spoof
#
# ['flac', 'LA_T_1473155', 'A01', 'spoof']
# In parse
# flac LA_T_3741411 A03 spoof
#
# ['flac', 'LA_T_3741411', 'A03', 'spoof']
# In parse
# flac LA_T_5786461 human human
#
# ['flac', 'LA_T_5786461', 'human', 'human']
# In parse
# flac LA_T_2613283 A01 spoof
#
# ['flac', 'LA_T_2613283', 'A01', 'spoof']
# In parse
# flac LA_T_1568794 A03 spoof
#
# ['flac', 'LA_T_1568794', 'A03', 'spoof']
# In parse
# flac LA_T_4219589 A04 spoof
#
# ['flac', 'LA_T_4219589', 'A04', 'spoof']
# In parse
# flac LA_T_8585187 A06 spoof
#
# ['flac', 'LA_T_8585187', 'A06', 'spoof']
# In parse
# flac LA_T_4014263 A02 spoof
#
# ['flac', 'LA_T_4014263', 'A02', 'spoof']
# In parse
# flac LA_T_4291948 A01 spoof
#
# ['flac', 'LA_T_4291948', 'A01', 'spoof']
# In parse
# flac LA_T_1226295 A01 spoof
#
# ['flac', 'LA_T_1226295', 'A01', 'spoof']
# In parse
# flac LA_T_3587040 A06 spoof
#
# ['flac', 'LA_T_3587040', 'A06', 'spoof']
# In parse
# flac LA_T_5702907 human human
#
# ['flac', 'LA_T_5702907', 'human', 'human']
# In parse
# flac LA_T_7642568 A04 spoof
#
# ['flac', 'LA_T_7642568', 'A04', 'spoof']
# In parse
# flac LA_T_9812275 A01 spoof
#
# ['flac', 'LA_T_9812275', 'A01', 'spoof']
# In parse
# flac LA_T_7875574 A06 spoof
#
# ['flac', 'LA_T_7875574', 'A06', 'spoof']
# In parse
# flac LA_T_7278744 A03 spoof
#
# ['flac', 'LA_T_7278744', 'A03', 'spoof']
# In parse
# flac LA_T_7692239 A02 spoof
#
# ['flac', 'LA_T_7692239', 'A02', 'spoof']
# In parse
# flac LA_T_3884343 A03 spoof
#
# ['flac', 'LA_T_3884343', 'A03', 'spoof']
# In parse
# flac LA_T_4016192 A03 spoof
#
# ['flac', 'LA_T_4016192', 'A03', 'spoof']
# In parse
# flac LA_T_9577378 A06 spoof
#
# ['flac', 'LA_T_9577378', 'A06', 'spoof']
# In parse
# flac LA_T_3784226 A06 spoof
#
# ['flac', 'LA_T_3784226', 'A06', 'spoof']
# In parse
# flac LA_T_6686104 human human
#
# ['flac', 'LA_T_6686104', 'human', 'human']
# In parse
# flac LA_T_9337751 A06 spoof
#
# ['flac', 'LA_T_9337751', 'A06', 'spoof']
# In parse
# flac LA_T_3972116 A01 spoof
#
# ['flac', 'LA_T_3972116', 'A01', 'spoof']
# In parse
# flac LA_T_1167878 A05 spoof
#
# ['flac', 'LA_T_1167878', 'A05', 'spoof']
# In parse
# flac LA_T_5453688 A01 spoof
#
# ['flac', 'LA_T_5453688', 'A01', 'spoof']
# In parse
# flac LA_T_4658222 A01 spoof
#
# ['flac', 'LA_T_4658222', 'A01', 'spoof']
# In parse
# flac LA_T_8135592 A04 spoof
#
# ['flac', 'LA_T_8135592', 'A04', 'spoof']
# In parse
# flac LA_T_7976997 A04 spoof
#
# ['flac', 'LA_T_7976997', 'A04', 'spoof']
# In parse
# flac LA_T_6101245 A04 spoof
#
# ['flac', 'LA_T_6101245', 'A04', 'spoof']
# Dataset saved to cache  cache_dev_LA_questo_devvv.npy

# %%
ds_eval = ASVDataset(feature_name='questo_eval', is_train=False, is_eval=True)
# Out:
# In parse
# flac LA_T_8211829 A06 spoof
#
# In parse
# flac LA_T_7155774 A01 spoof
#
# In parse
# flac LA_T_9073495 A04 spoof
#
# In parse
# flac LA_T_4209095 A04 spoof
#
# In parse
# flac LA_T_2946398 A01 spoof
#
# In parse
# flac LA_T_6246134 A03 spoof
#
# In parse
# flac LA_T_3780870 A04 spoof
#
# In parse
# flac LA_T_3965629 A06 spoof
#
# In parse
# flac LA_T_2088865 A02 spoof
#
# In parse
# flac LA_T_9580070 A05 spoof
#
# In parse
# flac LA_T_7698914 human human
#
# In parse
# flac LA_T_6655535 A02 spoof
#
# In parse
# flac LA_T_3164524 A01 spoof
#
# In parse
# flac LA_T_8185768 A06 spoof
#
# In parse
# flac LA_T_1054176 A03 spoof
#
# In parse
# flac LA_T_9162513 human human
#
# In parse
# flac LA_T_2834141 A04 spoof
#
# In parse
# flac LA_T_9493769 A06 spoof
#
# In parse
# flac LA_T_1659801 A03 spoof
#
# In parse
# flac LA_T_4294152 A02 spoof
#
# In parse
# flac LA_T_2217523 human human
#
# In parse
# flac LA_T_8318685 A03 spoof
#
# In parse
# flac LA_T_9366267 A04 spoof
#
# In parse
# flac LA_T_6927360 A01 spoof
#
# In parse
# flac LA_T_6639919 A03 spoof
#
# In parse
# flac LA_T_4408598 A01 spoof
#
# In parse
# flac LA_T_9362423 A06 spoof
#
# In parse
# flac LA_T_2822122 A06 spoof
#
# In parse
# flac LA_T_3541459 A06 spoof
#
# In parse
# flac LA_T_2871247 A03 spoof
#
# In parse
# flac LA_T_5339905 A04 spoof
#
# In parse
# flac LA_T_3781693 A03 spoof
#
# In parse
# flac LA_T_5514998 A04 spoof
#
# In parse
# flac LA_T_3643820 A03 spoof
#
# In parse
# flac LA_T_8773439 A06 spoof
#
# In parse
# flac LA_T_7908596 A01 spoof
#
# In parse
# flac LA_T_8459875 human human
#
# In parse
# flac LA_T_3969759 human human
#
# In parse
# flac LA_T_4972901 A04 spoof
#
# In parse
# flac LA_T_7846560 A05 spoof
#
# In parse
# flac LA_T_6918438 A01 spoof
#
# In parse
# flac LA_T_8631539 A02 spoof
#
# In parse
# flac LA_T_9916946 A01 spoof
#
# In parse
# flac LA_T_7975611 A01 spoof
#
# In parse
# flac LA_T_6647176 A04 spoof
#
# In parse
# flac LA_T_6456095 A06 spoof
#
# In parse
# flac LA_T_5834280 A01 spoof
#
# In parse
# flac LA_T_7633686 human human
#
# In parse
# flac LA_T_5540321 A05 spoof
#
# In parse
# flac LA_T_6975090 A04 spoof
#
# In parse
# flac LA_T_6441648 A04 spoof
#
# In parse
# flac LA_T_2818274 A05 spoof
#
# In parse
# flac LA_T_8633728 A04 spoof
#
# In parse
# flac LA_T_6653021 A06 spoof
#
# In parse
# flac LA_T_1789425 A06 spoof
#
# In parse
# flac LA_T_7166202 A03 spoof
#
# In parse
# flac LA_T_7371162 A03 spoof
#
# In parse
# flac LA_T_7910114 A02 spoof
#
# In parse
# flac LA_T_1362412 A06 spoof
#
# In parse
# flac LA_T_3331975 A01 spoof
#
# In parse
# flac LA_T_1991672 A05 spoof
#
# In parse
# flac LA_T_7803296 A01 spoof
#
# In parse
# flac LA_T_2763247 A03 spoof
#
# In parse
# flac LA_T_6566146 human human
#
# In parse
# flac LA_T_3977777 A02 spoof
#
# In parse
# flac LA_T_9698582 A01 spoof
#
# In parse
# flac LA_T_5427599 A05 spoof
#
# In parse
# flac LA_T_2800143 A04 spoof
#
# In parse
# flac LA_T_7600154 A06 spoof
#
# In parse
# flac LA_T_5604251 A02 spoof
#
# In parse
# flac LA_T_3197072 human human
#
# In parse
# flac LA_T_3581859 A05 spoof
#
# In parse
# flac LA_T_6994762 A02 spoof
#
# In parse
# flac LA_T_8811613 A02 spoof
#
# In parse
# flac LA_T_3771957 A06 spoof
#
# In parse
# flac LA_T_2151196 A02 spoof
#
# In parse
# flac LA_T_6521388 human human
#
# In parse
# flac LA_T_4981097 A04 spoof
#
# In parse
# flac LA_T_7336869 A02 spoof
#
# In parse
# flac LA_T_6159048 A04 spoof
#
# In parse
# flac LA_T_3236371 A04 spoof
#
# In parse
# flac LA_T_1683467 human human
#
# In parse
# flac LA_T_2050190 A06 spoof
#
# In parse
# flac LA_T_1581890 A04 spoof
#
# In parse
# flac LA_T_7405071 A04 spoof
#
# In parse
# flac LA_T_9622854 human human
#
# In parse
# flac LA_T_6208966 A01 spoof
#
# In parse
# flac LA_T_9482831 A02 spoof
#
# In parse
# flac LA_T_1810211 A04 spoof
#
# In parse
# flac LA_T_4401603 A05 spoof
#
# In parse
# flac LA_T_3441209 A02 spoof
#
# In parse
# flac LA_T_9628764 A01 spoof
#
# In parse
# flac LA_T_6131955 A03 spoof
#
# In parse
# flac LA_T_3849291 A04 spoof
#
# In parse
# flac LA_T_3084808 A06 spoof
#
# In parse
# flac LA_T_2644485 A01 spoof
#
# In parse
# flac LA_T_7667992 human human
#
# In parse
# flac LA_T_4131797 A02 spoof
#
# In parse
# flac LA_T_1092563 A01 spoof
#
# In parse
# flac LA_T_2951940 A01 spoof
#
# In parse
# flac LA_T_5580502 A06 spoof
#
# In parse
# flac LA_T_1259699 A04 spoof
#
# In parse
# flac LA_T_9976843 A02 spoof
#
# In parse
# flac LA_T_2474244 human human
#
# In parse
# flac LA_T_2577614 A04 spoof
#
# In parse
# flac LA_T_2664443 A01 spoof
#
# In parse
# flac LA_T_6376330 A04 spoof
#
# In parse
# flac LA_T_8349337 A05 spoof
#
# In parse
# flac LA_T_2313160 A02 spoof
#
# In parse
# flac LA_T_8337365 A03 spoof
#
# In parse
# flac LA_T_8309909 A05 spoof
#
# In parse
# flac LA_T_6835345 human human
#
# In parse
# flac LA_T_2958575 A01 spoof
#
# In parse
# flac LA_T_5729398 A04 spoof
#
# In parse
# flac LA_T_4962438 A06 spoof
#
# In parse
# flac LA_T_1007408 A03 spoof
#
# In parse
# flac LA_T_2914253 A01 spoof
#
# In parse
# flac LA_T_1963301 A03 spoof
#
# In parse
# flac LA_T_3475018 A03 spoof
#
# In parse
# flac LA_T_1355755 A04 spoof
#
# In parse
# flac LA_T_3689990 A05 spoof
#
# In parse
# flac LA_T_2808599 A06 spoof
#
# In parse
# flac LA_T_2787286 A03 spoof
#
# In parse
# flac LA_T_5876658 A03 spoof
#
# In parse
# flac LA_T_8035016 A01 spoof
#
# In parse
# flac LA_T_5448692 A02 spoof
#
# In parse
# flac LA_T_7511088 A05 spoof
#
# In parse
# flac LA_T_9085745 A05 spoof
#
# In parse
# flac LA_T_4585739 A03 spoof
#
# In parse
# flac LA_T_1040088 A01 spoof
#
# In parse
# flac LA_T_6521929 A01 spoof
#
# In parse
# flac LA_T_8147818 human human
#
# In parse
# flac LA_T_1210725 A04 spoof
#
# In parse
# flac LA_T_3940741 A01 spoof
#
# In parse
# flac LA_T_5002945 A01 spoof
#
# In parse
# flac LA_T_4917584 A06 spoof
#
# In parse
# flac LA_T_2534926 A04 spoof
#
# In parse
# flac LA_T_5048654 A03 spoof
#
# In parse
# flac LA_T_5103355 A02 spoof
#
# In parse
# flac LA_T_6884567 A06 spoof
#
# In parse
# flac LA_T_4050802 human human
#
# In parse
# flac LA_T_7226623 human human
#
# In parse
# flac LA_T_3291562 A04 spoof
#
# In parse
# flac LA_T_4784433 A01 spoof
#
# In parse
# flac LA_T_1602691 A02 spoof
#
# In parse
# flac LA_T_5277165 A02 spoof
#
# In parse
# flac LA_T_2547751 human human
#
# In parse
# flac LA_T_8539278 A03 spoof
#
# In parse
# flac LA_T_8604897 A01 spoof
#
# In parse
# flac LA_T_9921685 A05 spoof
#
# In parse
# flac LA_T_5703990 A03 spoof
#
# In parse
# flac LA_T_7426735 A06 spoof
#
# In parse
# flac LA_T_6283795 A05 spoof
#
# In parse
# flac LA_T_3833546 A03 spoof
#
# In parse
# flac LA_T_7359423 A02 spoof
#
# In parse
# flac LA_T_3310294 A06 spoof
#
# In parse
# flac LA_T_5789147 A02 spoof
#
# In parse
# flac LA_T_2182954 A03 spoof
#
# In parse
# flac LA_T_9304398 A04 spoof
#
# In parse
# flac LA_T_5252658 A06 spoof
#
# In parse
# flac LA_T_7221905 A02 spoof
#
# In parse
# flac LA_T_4131111 A02 spoof
#
# In parse
# flac LA_T_7781124 A06 spoof
#
# In parse
# flac LA_T_1759425 A01 spoof
#
# In parse
# flac LA_T_2682425 human human
#
# In parse
# flac LA_T_4035493 A02 spoof
#
# In parse
# flac LA_T_9626391 A05 spoof
#
# In parse
# flac LA_T_2988067 A03 spoof
#
# In parse
# flac LA_T_2405515 A03 spoof
#
# In parse
# flac LA_T_6625910 A02 spoof
#
# In parse
# flac LA_T_3867300 A01 spoof
#
# In parse
# flac LA_T_4785748 A06 spoof
#
# In parse
# flac LA_T_7697985 human human
#
# In parse
# flac LA_T_7523554 A06 spoof
#
# In parse
# flac LA_T_7509385 A06 spoof
#
# In parse
# flac LA_T_1956054 A05 spoof
#
# In parse
# flac LA_T_8845701 A06 spoof
#
# In parse
# flac LA_T_4307976 A02 spoof
#
# In parse
# flac LA_T_7233209 human human
#
# In parse
# flac LA_T_4134163 A04 spoof
#
# In parse
# flac LA_T_9288476 A01 spoof
#
# In parse
# flac LA_T_9810384 A03 spoof
#
# In parse
# flac LA_T_8171361 A04 spoof
#
# In parse
# flac LA_T_7156377 A02 spoof
#
# In parse
# flac LA_T_9840741 A03 spoof
#
# In parse
# flac LA_T_4685563 A03 spoof
#
# In parse
# flac LA_T_9396635 A01 spoof
#
# In parse
# flac LA_T_7700199 A05 spoof
#
# In parse
# flac LA_T_2350573 A03 spoof
#
# In parse
# flac LA_T_9048829 A01 spoof
#
# In parse
# flac LA_T_8681938 A05 spoof
#
# In parse
# flac LA_T_1201205 A04 spoof
#
# In parse
# flac LA_T_8008627 A04 spoof
#
# In parse
# flac LA_T_6117487 human human
#
# In parse
# flac LA_T_8225588 A02 spoof
#
# In parse
# flac LA_T_1681988 A02 spoof
#
# In parse
# flac LA_T_2561977 A02 spoof
#
# In parse
# flac LA_T_2602343 A05 spoof
#
# In parse
# flac LA_T_6185635 A06 spoof
#
# In parse
# flac LA_T_9470086 A02 spoof
#
# In parse
# flac LA_T_2652446 A04 spoof
#
# In parse
# flac LA_T_7355085 A02 spoof
#
# In parse
# flac LA_T_2607714 A05 spoof
#
# In parse
# flac LA_T_5843257 A06 spoof
#
# In parse
# flac LA_T_6771471 A02 spoof
#
# In parse
# flac LA_T_3893217 A04 spoof
#
# In parse
# flac LA_T_2737588 human human
#
# In parse
# flac LA_T_6313858 A03 spoof
#
# In parse
# flac LA_T_4895817 A04 spoof
#
# In parse
# flac LA_T_7423898 A03 spoof
#
# In parse
# flac LA_T_7000553 A04 spoof
#
# In parse
# flac LA_T_3884937 A01 spoof
#
# In parse
# flac LA_T_5016212 A01 spoof
#
# In parse
# flac LA_T_7899073 A06 spoof
#
# In parse
# flac LA_T_7805205 A05 spoof
#
# In parse
# flac LA_T_5078809 A02 spoof
#
# In parse
# flac LA_T_8969970 A02 spoof
#
# In parse
# flac LA_T_5448075 A06 spoof
#
# In parse
# flac LA_T_4243111 A02 spoof
#
# In parse
# flac LA_T_9224171 A02 spoof
#
# In parse
# flac LA_T_8707664 A02 spoof
#
# In parse
# flac LA_T_9226005 human human
#
# In parse
# flac LA_T_6591721 A01 spoof
#
# In parse
# flac LA_T_8615573 A02 spoof
#
# In parse
# flac LA_T_1575962 A05 spoof
#
# In parse
# flac LA_T_5850475 A05 spoof
#
# In parse
# flac LA_T_1903788 A02 spoof
#
# In parse
# flac LA_T_8570998 A06 spoof
#
# In parse
# flac LA_T_5407710 A01 spoof
#
# In parse
# flac LA_T_6132689 A06 spoof
#
# In parse
# flac LA_T_6161736 A01 spoof
#
# In parse
# flac LA_T_3104365 A06 spoof
#
# In parse
# flac LA_T_6852326 A03 spoof
#
# In parse
# flac LA_T_1664424 A06 spoof
#
# In parse
# flac LA_T_3394997 A03 spoof
#
# In parse
# flac LA_T_2854491 A05 spoof
#
# In parse
# flac LA_T_7108923 human human
#
# In parse
# flac LA_T_9334568 A03 spoof
#
# In parse
# flac LA_T_6540295 A02 spoof
#
# In parse
# flac LA_T_4627481 A05 spoof
#
# In parse
# flac LA_T_7872164 A02 spoof
#
# In parse
# flac LA_T_5820441 A01 spoof
#
# In parse
# flac LA_T_7900747 A03 spoof
#
# In parse
# flac LA_T_7690654 A05 spoof
#
# In parse
# flac LA_T_5706941 A02 spoof
#
# In parse
# flac LA_T_8031896 A06 spoof
#
# In parse
# flac LA_T_8947513 A04 spoof
#
# In parse
# flac LA_T_7771973 A04 spoof
#
# In parse
# flac LA_T_5526897 A03 spoof
#
# In parse
# flac LA_T_8259440 A06 spoof
#
# In parse
# flac LA_T_7454115 A03 spoof
#
# In parse
# flac LA_T_6525292 A04 spoof
#
# In parse
# flac LA_T_6577092 A05 spoof
#
# In parse
# flac LA_T_1780590 A01 spoof
#
# In parse
# flac LA_T_7600789 A04 spoof
#
# In parse
# flac LA_T_9684860 A04 spoof
#
# In parse
# flac LA_T_7744549 A06 spoof
#
# In parse
# flac LA_T_3704769 A06 spoof
#
# In parse
# flac LA_T_7692001 A04 spoof
#
# In parse
# flac LA_T_6193374 A05 spoof
#
# In parse
# flac LA_T_1165581 A02 spoof
#
# In parse
# flac LA_T_8464028 A06 spoof
#
# In parse
# flac LA_T_1555189 human human
#
# In parse
# flac LA_T_9936848 A02 spoof
#
# In parse
# flac LA_T_3777813 A02 spoof
#
# In parse
# flac LA_T_3119684 A03 spoof
#
# In parse
# flac LA_T_8996669 A02 spoof
#
# In parse
# flac LA_T_8880553 A03 spoof
#
# In parse
# flac LA_T_4682842 human human
#
# In parse
# flac LA_T_7523397 A03 spoof
#
# In parse
# flac LA_T_7535541 A03 spoof
#
# In parse
# flac LA_T_5706702 A06 spoof
#
# In parse
# flac LA_T_1012583 A01 spoof
#
# In parse
# flac LA_T_9854823 human human
#
# In parse
# flac LA_T_1457116 A02 spoof
#
# In parse
# flac LA_T_9263335 A05 spoof
#
# In parse
# flac LA_T_6928926 A01 spoof
#
# In parse
# flac LA_T_5779903 A02 spoof
#
# In parse
# flac LA_T_6442639 human human
#
# In parse
# flac LA_T_2561360 A06 spoof
#
# In parse
# flac LA_T_9481343 A02 spoof
#
# In parse
# flac LA_T_3042376 A06 spoof
#
# In parse
# flac LA_T_6309353 A01 spoof
#
# In parse
# flac LA_T_1667179 A05 spoof
#
# In parse
# flac LA_T_8188113 A01 spoof
#
# In parse
# flac LA_T_2411935 A02 spoof
#
# In parse
# flac LA_T_7238609 A03 spoof
#
# In parse
# flac LA_T_8708087 human human
#
# In parse
# flac LA_T_6283166 A01 spoof
#
# In parse
# flac LA_T_6958518 A03 spoof
#
# In parse
# flac LA_T_4118756 A02 spoof
#
# In parse
# flac LA_T_4494495 human human
#
# In parse
# flac LA_T_3324185 A01 spoof
#
# In parse
# flac LA_T_7707105 A01 spoof
#
# In parse
# flac LA_T_5520893 A04 spoof
#
# In parse
# flac LA_T_2762548 A02 spoof
#
# In parse
# flac LA_T_5078915 A02 spoof
#
# In parse
# flac LA_T_1228221 A05 spoof
#
# In parse
# flac LA_T_3693339 A04 spoof
#
# In parse
# flac LA_T_7120092 A03 spoof
#
# In parse
# flac LA_T_4417389 A06 spoof
#
# In parse
# flac LA_T_7663964 A05 spoof
#
# In parse
# flac LA_T_4327485 A02 spoof
#
# In parse
# flac LA_T_8451962 A06 spoof
#
# In parse
# flac LA_T_6911273 A01 spoof
#
# In parse
# flac LA_T_6738842 A01 spoof
#
# In parse
# flac LA_T_9682206 A01 spoof
#
# In parse
# flac LA_T_2872807 A03 spoof
#
# In parse
# flac LA_T_8580995 A02 spoof
#
# In parse
# flac LA_T_1780194 A01 spoof
#
# In parse
# flac LA_T_2788845 A02 spoof
#
# In parse
# flac LA_T_8928463 A01 spoof
#
# In parse
# flac LA_T_4450108 human human
#
# In parse
# flac LA_T_4581865 A03 spoof
#
# In parse
# flac LA_T_8511137 A03 spoof
#
# In parse
# flac LA_T_8173577 A03 spoof
#
# In parse
# flac LA_T_6401991 A04 spoof
#
# In parse
# flac LA_T_7259208 A02 spoof
#
# In parse
# flac LA_T_2854498 A03 spoof
#
# In parse
# flac LA_T_3429410 A02 spoof
#
# In parse
# flac LA_T_2047410 A04 spoof
#
# In parse
# flac LA_T_1887242 A04 spoof
#
# In parse
# flac LA_T_3553895 A01 spoof
#
# In parse
# flac LA_T_5486913 A03 spoof
#
# In parse
# flac LA_T_5076460 A04 spoof
#
# In parse
# flac LA_T_3054838 A02 spoof
#
# In parse
# flac LA_T_3415113 A05 spoof
#
# In parse
# flac LA_T_1880729 A01 spoof
#
# In parse
# flac LA_T_5808768 A03 spoof
#
# In parse
# flac LA_T_8825378 A05 spoof
#
# In parse
# flac LA_T_3779566 A04 spoof
#
# In parse
# flac LA_T_3026809 A01 spoof
#
# In parse
# flac LA_T_6524013 human human
#
# In parse
# flac LA_T_2649016 A06 spoof
#
# In parse
# flac LA_T_4754661 A02 spoof
#
# In parse
# flac LA_T_9378495 human human
#
# In parse
# flac LA_T_2209315 A01 spoof
#
# In parse
# flac LA_T_3682404 A05 spoof
#
# In parse
# flac LA_T_8690927 human human
#
# In parse
# flac LA_T_2894153 A03 spoof
#
# In parse
# flac LA_T_3051265 A03 spoof
#
# In parse
# flac LA_T_8156237 human human
#
# In parse
# flac LA_T_5186240 A04 spoof
#
# In parse
# flac LA_T_1275090 A05 spoof
#
# In parse
# flac LA_T_3073006 A02 spoof
#
# In parse
# flac LA_T_1379137 A04 spoof
#
# In parse
# flac LA_T_4270240 A01 spoof
#
# In parse
# flac LA_T_9916443 A04 spoof
#
# In parse
# flac LA_T_7171724 A04 spoof
#
# In parse
# flac LA_T_7332021 A04 spoof
#
# In parse
# flac LA_T_9181464 human human
#
# In parse
# flac LA_T_2324368 human human
#
# In parse
# flac LA_T_6717796 A05 spoof
#
# In parse
# flac LA_T_6952394 A04 spoof
#
# In parse
# flac LA_T_1590800 human human
#
# In parse
# flac LA_T_5445518 A04 spoof
#
# In parse
# flac LA_T_9502985 A05 spoof
#
# In parse
# flac LA_T_7904016 A06 spoof
#
# In parse
# flac LA_T_3759963 A04 spoof
#
# In parse
# flac LA_T_6023008 A01 spoof
#
# In parse
# flac LA_T_5450218 A02 spoof
#
# In parse
# flac LA_T_1203724 A02 spoof
#
# In parse
# flac LA_T_1480988 A03 spoof
#
# In parse
# flac LA_T_8983309 A02 spoof
#
# In parse
# flac LA_T_1138215 human human
#
# In parse
# flac LA_T_9632470 A03 spoof
#
# In parse
# flac LA_T_1590397 A02 spoof
#
# In parse
# flac LA_T_2642014 human human
#
# In parse
# flac LA_T_9640395 A02 spoof
#
# In parse
# flac LA_T_9633086 A05 spoof
#
# In parse
# flac LA_T_5109811 A02 spoof
#
# In parse
# flac LA_T_6345474 A05 spoof
#
# In parse
# flac LA_T_6966911 A04 spoof
#
# In parse
# flac LA_T_5005631 A02 spoof
#
# In parse
# flac LA_T_6909192 A03 spoof
#
# In parse
# flac LA_T_7486361 A03 spoof
#
# In parse
# flac LA_T_1744427 human human
#
# In parse
# flac LA_T_2949772 A04 spoof
#
# In parse
# flac LA_T_2810783 A05 spoof
#
# In parse
# flac LA_T_3935837 A05 spoof
#
# In parse
# flac LA_T_6525992 A03 spoof
#
# In parse
# flac LA_T_8243493 A06 spoof
#
# In parse
# flac LA_T_2735896 A04 spoof
#
# In parse
# flac LA_T_9068162 human human
#
# In parse
# flac LA_T_3832964 A05 spoof
#
# In parse
# flac LA_T_8406430 A02 spoof
#
# In parse
# flac LA_T_2135722 A06 spoof
#
# In parse
# flac LA_T_4040987 A06 spoof
#
# In parse
# flac LA_T_4352719 A03 spoof
#
# In parse
# flac LA_T_1494819 A06 spoof
#
# In parse
# flac LA_T_8696103 A04 spoof
#
# In parse
# flac LA_T_1626908 A06 spoof
#
# In parse
# flac LA_T_3508258 A06 spoof
#
# In parse
# flac LA_T_1894908 A06 spoof
#
# In parse
# flac LA_T_1132062 A06 spoof
#
# In parse
# flac LA_T_4876631 A04 spoof
#
# In parse
# flac LA_T_6908589 A03 spoof
#
# In parse
# flac LA_T_7461076 A01 spoof
#
# In parse
# flac LA_T_5576506 human human
#
# In parse
# flac LA_T_4768074 A03 spoof
#
# In parse
# flac LA_T_2587709 A02 spoof
#
# In parse
# flac LA_T_8574359 A05 spoof
#
# In parse
# flac LA_T_3795219 A06 spoof
#
# In parse
# flac LA_T_3313430 A02 spoof
#
# In parse
# flac LA_T_6970459 A01 spoof
#
# In parse
# flac LA_T_9736186 A06 spoof
#
# In parse
# flac LA_T_6535640 A05 spoof
#
# In parse
# flac LA_T_4941896 A01 spoof
#
# In parse
# flac LA_T_5568290 A05 spoof
#
# In parse
# flac LA_T_4798450 A02 spoof
#
# In parse
# flac LA_T_4380971 A06 spoof
#
# In parse
# flac LA_T_5228350 A06 spoof
#
# In parse
# flac LA_T_4833102 A05 spoof
#
# In parse
# flac LA_T_3650974 A02 spoof
#
# In parse
# flac LA_T_4686775 A05 spoof
#
# In parse
# flac LA_T_2280484 A02 spoof
#
# In parse
# flac LA_T_4004910 A03 spoof
#
# In parse
# flac LA_T_3645678 A05 spoof
#
# In parse
# flac LA_T_7110468 A02 spoof
#
# In parse
# flac LA_T_3381321 A06 spoof
#
# In parse
# flac LA_T_7938158 A04 spoof
#
# In parse
# flac LA_T_2388925 A03 spoof
#
# In parse
# flac LA_T_8896720 human human
#
# In parse
# flac LA_T_1815374 A02 spoof
#
# In parse
# flac LA_T_9966635 A03 spoof
#
# In parse
# flac LA_T_9411527 A03 spoof
#
# In parse
# flac LA_T_5895671 A03 spoof
#
# In parse
# flac LA_T_9912890 human human
#
# In parse
# flac LA_T_8546019 A04 spoof
#
# In parse
# flac LA_T_3547369 A03 spoof
#
# In parse
# flac LA_T_5384817 A02 spoof
#
# In parse
# flac LA_T_6780225 A01 spoof
#
# In parse
# flac LA_T_5673509 A05 spoof
#
# In parse
# flac LA_T_5114955 A04 spoof
#
# In parse
# flac LA_T_5720841 A03 spoof
#
# In parse
# flac LA_T_7922991 A02 spoof
#
# In parse
# flac LA_T_4398364 A04 spoof
#
# In parse
# flac LA_T_4557069 A03 spoof
#
# In parse
# flac LA_T_2989549 A03 spoof
#
# In parse
# flac LA_T_4451472 human human
#
# In parse
# flac LA_T_2195699 A02 spoof
#
# In parse
# flac LA_T_8460614 A02 spoof
#
# In parse
# flac LA_T_3130906 A06 spoof
#
# In parse
# flac LA_T_3197672 A05 spoof
#
# In parse
# flac LA_T_3630559 A04 spoof
#
# In parse
# flac LA_T_1631270 A01 spoof
#
# In parse
# flac LA_T_3147687 A03 spoof
#
# In parse
# flac LA_T_6197698 A01 spoof
#
# In parse
# flac LA_T_4098361 A05 spoof
#
# In parse
# flac LA_T_6235356 A05 spoof
#
# In parse
# flac LA_T_3786735 A01 spoof
#
# In parse
# flac LA_T_5646271 A06 spoof
#
# In parse
# flac LA_T_6723747 A05 spoof
#
# In parse
# flac LA_T_4172046 A03 spoof
#
# In parse
# flac LA_T_9321757 human human
#
# In parse
# flac LA_T_3265993 A02 spoof
#
# In parse
# flac LA_T_2848953 A06 spoof
#
# In parse
# flac LA_T_8195897 A02 spoof
#
# In parse
# flac LA_T_8176264 human human
#
# In parse
# flac LA_T_4970696 A03 spoof
#
# In parse
# flac LA_T_8861285 A03 spoof
#
# In parse
# flac LA_T_7783663 A01 spoof
#
# In parse
# flac LA_T_9072671 A06 spoof
#
# In parse
# flac LA_T_2359648 A01 spoof
#
# In parse
# flac LA_T_5916449 A05 spoof
#
# In parse
# flac LA_T_3707104 human human
#
# In parse
# flac LA_T_3220265 A06 spoof
#
# In parse
# flac LA_T_1894676 A01 spoof
#
# In parse
# flac LA_T_3889383 A05 spoof
#
# In parse
# flac LA_T_6585364 A06 spoof
#
# In parse
# flac LA_T_2879044 A03 spoof
#
# In parse
# flac LA_T_5752277 A03 spoof
#
# In parse
# flac LA_T_6807168 human human
#
# In parse
# flac LA_T_5755276 A05 spoof
#
# In parse
# flac LA_T_1315171 A02 spoof
#
# In parse
# flac LA_T_2712311 A03 spoof
#
# In parse
# flac LA_T_1533635 A04 spoof
#
# In parse
# flac LA_T_8006217 A03 spoof
#
# In parse
# flac LA_T_5866389 A04 spoof
#
# In parse
# flac LA_T_5080529 A03 spoof
#
# In parse
# flac LA_T_8463844 A03 spoof
#
# In parse
# flac LA_T_9475462 A02 spoof
#
# In parse
# flac LA_T_2891055 A02 spoof
#
# In parse
# flac LA_T_5038210 A03 spoof
#
# In parse
# flac LA_T_6239374 A02 spoof
#
# In parse
# flac LA_T_2536131 A05 spoof
#
# In parse
# flac LA_T_1215413 A06 spoof
#
# In parse
# flac LA_T_9233171 A06 spoof
#
# In parse
# flac LA_T_5065071 A02 spoof
#
# In parse
# flac LA_T_7123183 A03 spoof
#
# In parse
# flac LA_T_7746591 human human
#
# In parse
# flac LA_T_5505552 A02 spoof
#
# In parse
# flac LA_T_6651095 human human
#
# In parse
# flac LA_T_1506001 A03 spoof
#
# In parse
# flac LA_T_6842441 A04 spoof
#
# In parse
# flac LA_T_7590799 human human
#
# In parse
# flac LA_T_1308292 A04 spoof
#
# In parse
# flac LA_T_4581453 A04 spoof
#
# In parse
# flac LA_T_4334529 A06 spoof
#
# In parse
# flac LA_T_3563552 A01 spoof
#
# In parse
# flac LA_T_4359585 A06 spoof
#
# In parse
# flac LA_T_4836952 A01 spoof
#
# In parse
# flac LA_T_5113958 A03 spoof
#
# In parse
# flac LA_T_5357782 A03 spoof
#
# In parse
# flac LA_T_1828227 A04 spoof
#
# In parse
# flac LA_T_5391441 A03 spoof
#
# In parse
# flac LA_T_5379646 A05 spoof
#
# In parse
# flac LA_T_1792021 A01 spoof
#
# In parse
# flac LA_T_3044859 A06 spoof
#
# In parse
# flac LA_T_1661773 human human
#
# In parse
# flac LA_T_9413709 A04 spoof
#
# In parse
# flac LA_T_1038101 A04 spoof
#
# In parse
# flac LA_T_1091140 A03 spoof
#
# In parse
# flac LA_T_7234844 human human
#
# In parse
# flac LA_T_1004644 A01 spoof
#
# In parse
# flac LA_T_2242703 A04 spoof
#
# In parse
# flac LA_T_6566870 A06 spoof
#
# In parse
# flac LA_T_3443367 A01 spoof
#
# In parse
# flac LA_T_4989128 A01 spoof
#
# In parse
# flac LA_T_8596135 A05 spoof
#
# In parse
# flac LA_T_7837386 A01 spoof
#
# In parse
# flac LA_T_3711779 A03 spoof
#
# In parse
# flac LA_T_4711971 A05 spoof
#
# In parse
# flac LA_T_5260333 human human
#
# In parse
# flac LA_T_7768656 A06 spoof
#
# In parse
# flac LA_T_8359685 A02 spoof
#
# In parse
# flac LA_T_8203135 A04 spoof
#
# In parse
# flac LA_T_7357774 A04 spoof
#
# In parse
# flac LA_T_9886167 A05 spoof
#
# In parse
# flac LA_T_6656631 A06 spoof
#
# In parse
# flac LA_T_9396818 A03 spoof
#
# In parse
# flac LA_T_5482669 A05 spoof
#
# In parse
# flac LA_T_5478706 A06 spoof
#
# In parse
# flac LA_T_2265802 A01 spoof
#
# In parse
# flac LA_T_1248092 human human
#
# In parse
# flac LA_T_4667722 A06 spoof
#
# In parse
# flac LA_T_5699355 A04 spoof
#
# In parse
# flac LA_T_8274550 A03 spoof
#
# In parse
# flac LA_T_7218005 A02 spoof
#
# In parse
# flac LA_T_2365439 A06 spoof
#
# In parse
# flac LA_T_4827379 A01 spoof
#
# In parse
# flac LA_T_8239711 A06 spoof
#
# In parse
# flac LA_T_5452933 A02 spoof
#
# In parse
# flac LA_T_1470113 A02 spoof
#
# In parse
# flac LA_T_1163956 A06 spoof
#
# In parse
# flac LA_T_6597160 A05 spoof
#
# In parse
# flac LA_T_1558208 A01 spoof
#
# In parse
# flac LA_T_3738524 A05 spoof
#
# In parse
# flac LA_T_6207461 A01 spoof
#
# In parse
# flac LA_T_4197086 A04 spoof
#
# In parse
# flac LA_T_2283503 A06 spoof
#
# In parse
# flac LA_T_2224464 A02 spoof
#
# In parse
# flac LA_T_2386893 A06 spoof
#
# In parse
# flac LA_T_8658136 A02 spoof
#
# In parse
# flac LA_T_4216855 A06 spoof
#
# In parse
# flac LA_T_3649480 human human
#
# In parse
# flac LA_T_8681379 A03 spoof
#
# In parse
# flac LA_T_7489501 A03 spoof
#
# In parse
# flac LA_T_9761954 A05 spoof
#
# In parse
# flac LA_T_9238209 A01 spoof
#
# In parse
# flac LA_T_9634710 A06 spoof
#
# In parse
# flac LA_T_9784384 A02 spoof
#
# In parse
# flac LA_T_9440881 A03 spoof
#
# In parse
# flac LA_T_4236108 A02 spoof
#
# In parse
# flac LA_T_8875666 A01 spoof
#
# In parse
# flac LA_T_2090843 A04 spoof
#
# In parse
# flac LA_T_4820526 A03 spoof
#
# In parse
# flac LA_T_3306341 A05 spoof
#
# In parse
# flac LA_T_7708952 human human
#
# In parse
# flac LA_T_7765738 A02 spoof
#
# In parse
# flac LA_T_3285771 A05 spoof
#
# In parse
# flac LA_T_5146287 A05 spoof
#
# In parse
# flac LA_T_7559219 A05 spoof
#
# In parse
# flac LA_T_1013068 A02 spoof
#
# In parse
# flac LA_T_1524989 A06 spoof
#
# In parse
# flac LA_T_6894346 A01 spoof
#
# In parse
# flac LA_T_8449962 A01 spoof
#
# In parse
# flac LA_T_5866278 A01 spoof
#
# In parse
# flac LA_T_4328032 A01 spoof
#
# In parse
# flac LA_T_8852908 A06 spoof
#
# In parse
# flac LA_T_8086458 human human
#
# In parse
# flac LA_T_8388659 A05 spoof
#
# In parse
# flac LA_T_1963537 A03 spoof
#
# In parse
# flac LA_T_7624012 A04 spoof
#
# In parse
# flac LA_T_3110916 human human
#
# In parse
# flac LA_T_5239634 A01 spoof
#
# In parse
# flac LA_T_1864954 A06 spoof
#
# In parse
# flac LA_T_2383672 A05 spoof
#
# In parse
# flac LA_T_6074546 A03 spoof
#
# In parse
# flac LA_T_3821309 A02 spoof
#
# In parse
# flac LA_T_4823797 A03 spoof
#
# In parse
# flac LA_T_2030012 A02 spoof
#
# In parse
# flac LA_T_9190599 human human
#
# In parse
# flac LA_T_8800306 A01 spoof
#
# In parse
# flac LA_T_5863415 A04 spoof
#
# In parse
# flac LA_T_4412351 A03 spoof
#
# In parse
# flac LA_T_8442575 A03 spoof
#
# In parse
# flac LA_T_6512141 A03 spoof
#
# In parse
# flac LA_T_7732642 A01 spoof
#
# In parse
# flac LA_T_9527593 A06 spoof
#
# In parse
# flac LA_T_9722032 A06 spoof
#
# In parse
# flac LA_T_3637010 A01 spoof
#
# In parse
# flac LA_T_2541690 A04 spoof
#
# In parse
# flac LA_T_5086026 A04 spoof
#
# In parse
# flac LA_T_6346187 A02 spoof
#
# In parse
# flac LA_T_6053949 A02 spoof
#
# In parse
# flac LA_T_4001750 A01 spoof
#
# In parse
# flac LA_T_1524490 A01 spoof
#
# In parse
# flac LA_T_4595239 A06 spoof
#
# In parse
# flac LA_T_4547012 A05 spoof
#
# In parse
# flac LA_T_3537468 A06 spoof
#
# In parse
# flac LA_T_1989869 A06 spoof
#
# In parse
# flac LA_T_6725220 A02 spoof
#
# In parse
# flac LA_T_9053669 A05 spoof
#
# In parse
# flac LA_T_5569411 A04 spoof
#
# In parse
# flac LA_T_7045399 A05 spoof
#
# In parse
# flac LA_T_4408459 A06 spoof
#
# In parse
# flac LA_T_4875626 A02 spoof
#
# In parse
# flac LA_T_9918358 A02 spoof
#
# In parse
# flac LA_T_4251187 A06 spoof
#
# In parse
# flac LA_T_4741940 A06 spoof
#
# In parse
# flac LA_T_6783567 A06 spoof
#
# In parse
# flac LA_T_6442486 human human
#
# In parse
# flac LA_T_8997434 A04 spoof
#
# In parse
# flac LA_T_9790727 A03 spoof
#
# In parse
# flac LA_T_3832697 A02 spoof
#
# In parse
# flac LA_T_7156201 A06 spoof
#
# In parse
# flac LA_T_9202802 A03 spoof
#
# In parse
# flac LA_T_4953420 A03 spoof
#
# In parse
# flac LA_T_7686633 human human
#
# In parse
# flac LA_T_7160568 A01 spoof
#
# In parse
# flac LA_T_5566818 A02 spoof
#
# In parse
# flac LA_T_7239412 A01 spoof
#
# In parse
# flac LA_T_1911966 A04 spoof
#
# In parse
# flac LA_T_3888800 A02 spoof
# Dataset saved to cache  cache_eval_LA_questo_eval.npy

# %%
cv2.imshow('final', ds_eval[0][0]) 
cv2.waitKey(0)   
cv2.destroyAllWindows()
